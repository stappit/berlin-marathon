# %% [markdown]
# # Cleaning the Dataset

# %% [markdown]
# ## Setup

# %%
import sys
sys.path.append('..')

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
import json
import os.path
import string
from scripts.scrape import get_json, get_metadata

# %%
data_folder = os.path.join('..', 'data')

dirty_filename = os.path.join(data_folder, 'berlin_marathon_times_dirty.csv')
clean_filename = os.path.join(data_folder, 'berlin_marathon_times.csv')

dirty_filename
# Out:
# '../data/berlin_marathon_times_dirty.csv'

# %%
df = pd.read_csv(dirty_filename).sort_values(['year', 'id']).reset_index(drop=True)
df.head()
# Out:
#    id  place    bib        surname     forename                  team  \
# 0   2  19431   2002    Ohnemueller  Bert Martin                   NaN
# 1   3  10609  29356     Klinginger         Kurt    smart running team
# 2   4  23031   2034  Eleftheriadis     Georgios                   NaN
# 3   5  14104   2035         Scholz       Detlef                   NaN
# 4   6  30239   F105       Frischke        Lucie  LAV Tempelhof Berlin
#
#   nationality   yob sex age_class  age_class_place  net_time clock_time  year
# 0         GER  1959   M       M45             2758  04:23:26   04:23:48  2005
# 1         GER  1947   M       M55              344  03:53:01   03:56:43  2005
# 2         GRE  1962   M       M40             4470  04:38:47   04:42:41  2005
# 3         GER  1970   M       M35             2573  04:03:50   04:05:14  2005
# 4         GER  1932   W       W70                2  06:07:10   06:09:04  2005

# %% [markdown]
# ## Completeness Check

# %%
participants_year = df.year.value_counts().sort_index()
participants_year
# Out:
# 2005    30373
# 2006    30182
# 2007    32486
# 2008    35731
# 2009    35015
# 2010    34001
# 2011    32914
# 2012    34270
# 2013    36473
# 2014    28945
# 2015    36753
# 2016    35991
# Name: year, dtype: int64

# %%
participants_year_meta = participants_year.copy()

for year in participants_year.index:
    with open('../data/{0}-1.json'.format(year)) as f:
        j = json.load(f)
        m = get_metadata(j)
        participants_year_meta[year] = m.n_rows
        
participants_year_meta
# Out:
# 2005    30373
# 2006    30182
# 2007    32486
# 2008    35731
# 2009    35015
# 2010    34001
# 2011    32914
# 2012    34270
# 2013    36473
# 2014    28945
# 2015    36753
# 2016    35991
# Name: year, dtype: int64

# %%
len(participants_year[participants_year != participants_year_meta])
# Out:
# 0

# %% [markdown]
# ## Overview

# %%
len(df)
# Out:
# 403134

# %%
df.dtypes
# Out:
# id                  int64
# place               int64
# bib                object
# surname            object
# forename           object
# team               object
# nationality        object
# yob                 int64
# sex                object
# age_class          object
# age_class_place     int64
# net_time           object
# clock_time         object
# year                int64
# dtype: object

# %%
df.describe()
# Out:
#                   id          place            yob  age_class_place  \
# count  403134.000000  403134.000000  403134.000000    403134.000000
# mean    26240.607041   16899.358593    1967.243013      1596.684058
# std     25441.663187    9861.602089      47.518969      1321.932040
# min         2.000000       1.000000       0.000000         0.000000
# 25%     10150.000000    8402.000000    1962.000000       517.000000
# 50%     20216.000000   16804.000000    1968.000000      1208.000000
# 75%     31350.000000   25206.000000    1976.000000      2456.000000
# max    141120.000000   36768.000000    1998.000000      6101.000000
#
#                 year
# count  403134.000000
# mean     2010.619734
# std         3.426661
# min      2005.000000
# 25%      2008.000000
# 50%      2011.000000
# 75%      2014.000000
# max      2016.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403134 entries, 0 to 403133
# Data columns (total 14 columns):
# id                 403134 non-null int64
# place              403134 non-null int64
# bib                403127 non-null object
# surname            403096 non-null object
# forename           403089 non-null object
# team               181573 non-null object
# nationality        403120 non-null object
# yob                403134 non-null int64
# sex                403132 non-null object
# age_class          403105 non-null object
# age_class_place    403134 non-null int64
# net_time           403134 non-null object
# clock_time         403134 non-null object
# year               403134 non-null int64
# dtypes: int64(5), object(9)
# memory usage: 43.1+ MB

# %% [markdown]
# # Unique IDs

# %%
id_counts = df.groupby('id').year.count()
id_problems = id_counts[id_counts > 1]
len(id_problems)
# Out:
# 58616

# %%
id_problems.describe()
# Out:
# count    58616.000000
# mean         6.602378
# std          3.688039
# min          2.000000
# 25%          2.000000
# 50%          8.000000
# 75%         10.000000
# max         12.000000
# Name: year, dtype: float64

# %%
ids = df.groupby(['id', 'year']).place.count()
ids_problems = ids[ids > 1]
len(ids_problems)
# Out:
# 0

# %% [markdown]
# ## Place

# %%
len(df[df.place.isnull()])
# Out:
# 0

# %%
df.place.describe()
# Out:
# count    403134.000000
# mean      16899.358593
# std        9861.602089
# min           1.000000
# 25%        8402.000000
# 50%       16804.000000
# 75%       25206.000000
# max       36768.000000
# Name: place, dtype: float64

# %% [markdown]
# ## Times

# %%
len(df[df.net_time.isnull()])
# Out:
# 0

# %%
len(df[df.clock_time.isnull()])
# Out:
# 0

# %%
df.net_time = pd.to_timedelta(df.net_time)
df.clock_time = pd.to_timedelta(df.clock_time)
df.net_time.describe()
# Out:
# count                    403134
# mean     0 days 04:09:00.199402
# std      0 days 00:42:32.086175
# min             0 days 00:00:00
# 25%             0 days 03:39:12
# 50%             0 days 04:04:23
# 75%             0 days 04:35:43
# max             0 days 08:41:33
# Name: net_time, dtype: object

# %%
df.clock_time.describe()
# Out:
# count                    403134
# mean     0 days 04:19:57.418917
# std      0 days 00:48:21.491980
# min             0 days 00:00:00
# 25%             0 days 03:45:24
# 50%             0 days 04:16:00
# 75%      0 days 04:51:08.750000
# max             0 days 11:01:11
# Name: clock_time, dtype: object

# %% [markdown]
# A time of zero seconds doesn't make sense so we replace it with null.

# %%
zero = pd.Timedelta(0)
len(df[df.net_time == zero])
# Out:
# 2

# %%
df.net_time = df.net_time.replace(zero, np.nan)
len(df[df.net_time == zero])
# Out:
# 0

# %%
len(df[df.clock_time == zero])
# Out:
# 6

# %%
df.clock_time = df.clock_time.replace(zero, np.nan)
len(df[df.clock_time == zero])
# Out:
# 0

# %%
times = df[df.net_time > df.clock_time]
times
# Out:
#            id  place    bib   surname forename                     team  \
# 58489   41853  22138  F4217     Vogel   Esther                      NaN
# 312161  11182   2673  13549  Sowisnki  Fabrice  SAINT VENANT ATHLETISME
#
#        nationality   yob sex age_class  age_class_place net_time clock_time  \
# 58489          DEU  1973   W       W30              524 04:41:51   04:26:20
# 312161         FRA  1974   M        40              595 03:13:55   02:58:59
#
#         year
# 58489   2006
# 312161  2014

# %%
ev = df.loc[58489]
fs = df.loc[312161]

# %%
df[(df.year == ev.year) & (ev.place - 4 < df.place) & (df.place < ev.place + 5)].sort_values('place')
# Out:
#           id  place    bib     surname     forename             team  \
# 38966   9778  22135  12254   von Blume         Marc  SV Blitzenreute
# 42175  13258  22136   8523       Kolke     Reinhard              NaN
# 52108  26030  22137  26910  Wojczewski  Axel-Rainer              NaN
# 46026  17899  22138  F3482       Lorch       Renate              NaN
# 58489  41853  22138  F4217       Vogel       Esther              NaN
# 43553  14787  22140  16772      Kaspar       Werner              NaN
# 59977  43398  22141  13745      Ruholl        Steve              NaN
# 53329  28360  22142  29253     Fortune  Jean Pierre              NaN
#
#       nationality   yob sex age_class  age_class_place net_time clock_time  \
# 38966         DEU  1962   M       M40             4357 04:41:50   04:43:48
# 42175         DEU  1968   M       M35             3544 04:41:50   04:43:41
# 52108         DEU  1949   M       M55              936 04:41:51   04:46:29
# 46026         DEU  1960   W       W45              579 04:41:51   04:47:42
# 58489         DEU  1973   W       W30              524 04:41:51   04:26:20
# 43553         DEU  1953   M       M50             1985 04:41:52   04:45:27
# 59977         DEU  1979   M        MH             1817 04:41:52   04:45:31
# 53329         FRA  1955   M       M50             1986 04:41:52   04:46:23
#
#        year
# 38966  2006
# 42175  2006
# 52108  2006
# 46026  2006
# 58489  2006
# 43553  2006
# 59977  2006
# 53329  2006

# %%
df.set_value(ev.name, 'clock_time', ev.clock_time + pd.Timedelta('20 min'))
df.loc[ev.name]
# Out:
# id                           41853
# place                        22138
# bib                          F4217
# surname                      Vogel
# forename                    Esther
# team                           NaN
# nationality                    DEU
# yob                           1973
# sex                              W
# age_class                      W30
# age_class_place                524
# net_time           0 days 04:41:51
# clock_time         0 days 04:46:20
# year                          2006
# Name: 58489, dtype: object

# %%
df[(df.year == fs.year) & (fs.place - 4 < df.place) & (df.place < fs.place + 5)].sort_values('place')
# Out:
#            id  place    bib     surname forename                     team  \
# 305127   3965   2670   6318       Borck      Jan          Der Kleine Muck
# 308016   6920   2671  26033    Schuller    Eelco                      PAC
# 329255  28776   2672   6185        Boge    Georg                      NaN
# 312161  11182   2673  13549    Sowisnki  Fabrice  SAINT VENANT ATHLETISME
# 306101   4960   2674   F597    Aljancic   Natasa               AK DOMALE
# 304271   3080   2675   7519    Chambers     Dion                      NaN
# 306792   5671   2676   7933     Colsman  Philipp                      NaN
# 327244  26721   2677  13784  Hinrichsen   Thomas               HRLK / BLL
#
#        nationality   yob sex age_class  age_class_place net_time clock_time  \
# 305127         DEU  1964   M        50              200 03:13:55   03:14:12
# 308016         NLD  1986   M         H              264 03:13:55   03:15:41
# 329255         DEU  1980   M        30              464 03:13:55   03:18:29
# 312161         FRA  1974   M        40              595 03:13:55   02:58:59
# 306101         SVN  1969   W        45               13 03:13:56   03:15:45
# 304271         GBR  1989   M         H              265 03:13:56   03:14:53
# 306792         DEU  1967   M        45              442 03:13:57   03:16:41
# 327244         DNK  1975   M        35              517 03:13:58   03:14:12
#
#         year
# 305127  2014
# 308016  2014
# 329255  2014
# 312161  2014
# 306101  2014
# 304271  2014
# 306792  2014
# 327244  2014

# %%
df.set_value(fs.name, 'clock_time', ev.clock_time + pd.Timedelta('20 min'))
df.loc[fs.name]
# Out:
# id                                   11182
# place                                 2673
# bib                                  13549
# surname                           Sowisnki
# forename                           Fabrice
# team               SAINT VENANT ATHLETISME
# nationality                            FRA
# yob                                   1974
# sex                                      M
# age_class                               40
# age_class_place                        595
# net_time                   0 days 03:13:55
# clock_time                 0 days 04:46:20
# year                                  2014
# Name: 312161, dtype: object

# %%
len(df[df.net_time > df.clock_time])
# Out:
# 0

# %% [markdown]
# ## Sex

# %%
df.sex.describe()
# Out:
# count     403132
# unique         2
# top            M
# freq      313715
# Name: sex, dtype: object

# %%
df.sex.value_counts()
# Out:
# M    313715
# W     89417
# Name: sex, dtype: int64

# %%
no_sex = df[df.sex.isnull()]
len(no_sex)
# Out:
# 2

# %%
no_sex
# Out:
#            id  place    bib    surname  forename team nationality   yob  sex  \
# 391937  77124  27472   6956     Barris   Wolfram  NaN         NaN  1951  NaN
# 392473  78774  26936  40651  Schnetzer  Wolfgang  NaN         NaN  1961  NaN
#
#        age_class  age_class_place net_time clock_time  year
# 391937       NaN              191 04:43:58   05:00:42  2016
# 392473       NaN             1509 04:41:32   05:15:56  2016

# %%
df.sex = df.sex.fillna('M').astype('category')
len(df[df.sex.isnull()])
# Out:
# 0

# %% [markdown]
# ## Year of Birth (YOB)

# %%
df.yob.describe()
# Out:
# count    403134.000000
# mean       1967.243013
# std          47.518969
# min           0.000000
# 25%        1962.000000
# 50%        1968.000000
# 75%        1976.000000
# max        1998.000000
# Name: yob, dtype: float64

# %%
len(df[df.yob.isnull()])
# Out:
# 0

# %%
df.yob = df.yob.replace(0, np.nan)
df.yob.describe()
# Out:
# count    402910.000000
# mean       1968.336713
# std          10.321517
# min        1901.000000
# 25%        1962.000000
# 50%        1968.000000
# 75%        1976.000000
# max        1998.000000
# Name: yob, dtype: float64

# %% [markdown]
# It is unlikely to have a YOB of 1901.

# %%
df.yob.value_counts().sort_index().head(10)
# Out:
# 1901.0    22
# 1902.0     3
# 1923.0     2
# 1925.0     2
# 1926.0     5
# 1927.0    12
# 1928.0    12
# 1929.0     8
# 1930.0    11
# 1931.0    22
# Name: yob, dtype: int64

# %%
df['age'] = df.year - df.yob
df[df.yob <= 1925].sort_values(['yob', 'age'], ascending=[True, False])[['year', 'yob', 'age', 'age_class', 'net_time', 'place', 'age_class_place']]
# Out:
#         year     yob    age age_class net_time  place  age_class_place
# 393222  2016  1901.0  115.0       NaN 03:05:59   2126                0
# 168821  2010  1901.0  109.0         W 04:00:01  16646                0
# 171914  2010  1901.0  109.0         M 04:09:04  19394                0
# 172694  2010  1901.0  109.0         M 03:54:42  14287                0
# 179028  2010  1901.0  109.0         M 04:50:29  29460                0
# 179175  2010  1901.0  109.0         W 05:02:11  31018                0
# 180154  2010  1901.0  109.0         M 04:09:35  19565                0
# 183176  2010  1901.0  109.0         M 03:08:16   2071                0
# 189399  2010  1901.0  109.0         M 03:40:54   9474                0
# 190564  2010  1901.0  109.0         M 03:41:56   9751                0
# 190944  2010  1901.0  109.0         W 05:01:29  30959                0
# 192247  2010  1901.0  109.0         M 02:49:48    460                0
# 193183  2010  1901.0  109.0         M 03:37:32   8467                0
# 195244  2010  1901.0  109.0         W 04:47:52  29034                0
# 130881  2009  1901.0  108.0        MH 04:33:53  24617             2274
# 139199  2009  1901.0  108.0        MH 04:40:52  26378             2405
# 155445  2009  1901.0  108.0        MH 03:57:45  13536             1340
# 156096  2009  1901.0  108.0        WH 04:43:34  27056              652
# 157318  2009  1901.0  108.0        MH 04:06:50  16460             1599
# 157658  2009  1901.0  108.0        MH 03:51:03  11064             1111
# 163345  2009  1901.0  108.0        MH 04:24:10  21907             2071
# 163347  2009  1901.0  108.0        MH 03:27:01   4755              557
# 174163  2010  1902.0  108.0         M 03:52:07  13285                0
# 179851  2010  1902.0  108.0         W 05:05:23  31290                0
# 159836  2009  1902.0  107.0        MH 03:13:28   2460              309
# 145928  2009  1923.0   86.0       M80 06:42:35  35006                5
# 103     2005  1923.0   82.0       M80 06:55:52  30381                2
# 64392   2007  1925.0   82.0       W80 06:01:59  32286                1
# 5959    2005  1925.0   80.0       M80 04:31:53  21492                1

# %%
df.yob = df.yob.replace(1901, np.nan).replace(1902, np.nan)
df['age'] = df.year - df.yob

# %% [markdown]
# Once we have cleaned up the age class, we can use this information to guess the YOB.

# %% [markdown]
# Are some listed as too young to participate?

# %%
df[df.age < 18]
# Out:
#            id  place    bib    surname       forename            team  \
# 2291     2685   7246   5257     Koepke        Mathias     Mahlower SV
# 4943     5704  26060   5466   Jacobsen  Eystein André             NaN
# 25172   31437   4107  29736  Petrausch          Janek   Schenker-TEAM
# 61428     915  20059   2446   Musielak         Norman             NaN
# 61659    1154  30028  F1332    Scharpf          Maria  Scharpf-Family
# 77385   17477  32343  F6340      Garbe        Tabitha             NaN
# 139060  10843  24928  22567  Oppermann        Patrick             NaN
# 167596   4134  20039  F8916   Forsberg          Sofie             MTC
#
#        nationality     yob sex age_class  age_class_place net_time clock_time  \
# 2291           GER  1988.0   M       MJA               18 03:40:18   03:40:58
# 4943           NOR  1988.0   M       MJA               97 04:55:34   04:59:23
# 25172          GER  1988.0   M       MJA                9 03:26:21   03:28:55
# 61428          DEU  1990.0   M       MJA               84 04:15:32   04:15:52
# 61659          DEU  1990.0   W       WJA               23 05:09:06   05:15:09
# 77385          DEU  1990.0   W       WJA               29 06:07:53   06:10:04
# 139060         DEU  1995.0   M       MJA               79 04:35:04   04:42:02
# 167596         DNK  1993.0   W       WJA                7 04:11:04   04:33:41
#
#         year   age
# 2291    2005  17.0
# 4943    2005  17.0
# 25172   2005  17.0
# 61428   2007  17.0
# 61659   2007  17.0
# 77385   2007  17.0
# 139060  2009  14.0
# 167596  2010  17.0

# %% [markdown]
# ## Age Class

# %%
df.age_class.value_counts().sort_index()
# Out:
# 30     25394
# 35     30177
# 40     38211
# 45     38433
# 50     28243
# 55     13845
# 60      6461
# 65      2477
# 70       971
# 75       255
# 80        37
# H      20298
# JA       420
# M         25
# M30    18301
# M35    26373
# M40    33912
# M45    27643
# M50    17945
# M55     9114
# M60     4376
# M65     2058
# M70      597
# M75       82
# M80       15
# MH     16315
# MJA      724
# U20       95
# W          8
# W30     5474
# W35     6598
# W40     8675
# W45     7093
# W50     4033
# W55     1618
# W60      584
# W65      251
# W70       50
# W75        3
# W80        5
# WH      5742
# WJA      174
# Name: age_class, dtype: int64

# %% [markdown]
# The age class groups are very inconsistent in their naming and many also contain information about the sex of the participant.  Before removing the sex from the age class, we can use it as a consistency check for the sex column

# %%
len(df[df.age_class.str.contains(r'[MW]', na=False)])
# Out:
# 197788

# %%
age_class_sex = df[df.age_class.str.contains(r'[MW]', na=False)].age_class.str.get(0)
inconsistent_sex0 = df.loc[age_class_sex.index, 'sex'] != age_class_sex
inconsistent_sex = df.loc[inconsistent_sex0[inconsistent_sex0 == True].index, :]
len(inconsistent_sex)
# Out:
# 34

# %%
inconsistent_sex
# Out:
#            id  place    bib      surname           forename  \
# 9201    10341   1532  F3923      Lohmann             Henrik
# 10108   11280  14344  F5717      Sanchez               Raul
# 19935   23704  10930  F4420      Kachlik            Stephan
# 20122   23897   7434  F5646    Kirchhoff             Jochen
# 23362   28829   9129  F6506         Pape             Gerald
# 26631   33336  21772  F8928     Tricoche          Elisabeth
# 30198   37786   6827  32681      Filippo           Proietti
# 30200   37789  20204  32699     Demetrio            Alberto
# 34335    4614   2110  F3676         Aeby     Pascal Laurent
# 44551   16028    106  F7055    Nordgaard            Haavard
# 58571   41938  19813  32282        Filho           Lourival
# 60290   43722   1571  F7523     Basdekis             Pavlos
# 60849     306  19484  F9642        Liden             Mikael
# 63342    2922  25182  F9645       Knaack             Oliver
# 66246    5922  12248  F2071  Himmelstein                Ari
# 66879    6571   3335  F9637       Holmes                Ben
# 69290    9038  32171  F9640     Wrzesien             Szymon
# 69574    9330  29549  F9643    Bergström            Fredrik
# 69640    9396   4775  33909  Ángel Ávila        Juan Manuel
# 69739    9497  24573  34121         Hyde               Kyle
# 80021   20252  15106  F9646      Eastman             Oliver
# 80944   21219   1270  F8957     Sørensen  Jytte Vestergaard
# 86445   29757   8923  34146        Frank         Vandenhole
# 86616   29964  26057  F9638      Richter              Frank
# 89023   33174  28164  F9639       Welber               Adam
# 92208   37911  20212    NaN      Middeke             Jasmin
# 96128    3667   4703  F1025       Maison             Sylvie
# 99806    7472  15536  37917       Macedo          Guilherme
# 102182   9951  23810  12454     Hautamaa               Anne
# 112288  20854  15085  37913      Michele              Tolin
# 120566  31461  22967  F5968      Morlang               René
# 124007  36818   4724  F7099        Rogoz           Grzegorz
# 124745  38362  16994  24442      Neuhaus             Svenja
# 126245  42364  33949  F9289      de Pape               Aldo
#
#                           team nationality     yob sex age_class  \
# 9201                    Sparta         DEN  1964.0   W       M40
# 10108                      NaN         SUI  1962.0   W       M40
# 19935                      NaN         GER  1963.0   W       M40
# 20122            TSV Bollensen         GER  1957.0   W       M45
# 23362       TriFrogs Gellersen         GER  1965.0   W       M40
# 26631             Defi Horizon         FRA  1949.0   W       M55
# 30198                      NaN         ITA  1967.0   M       W35
# 30200                      NaN         BRA  1965.0   M       W40
# 34335                      NaN         DEU  1966.0   W       M40
# 44551                     Nike         NOR  1961.0   W       M45
# 58571                   Brazil         BRA  1957.0   M       W45
# 60290                      NaN         GRC  1946.0   W       M60
# 60849                      NaN         SWE  1970.0   W       M35
# 63342     Berlin Sluggers e.V.         DEU  1969.0   W       M35
# 66246             The Team R&F         BRA  1961.0   W       M45
# 66879                      NaN         GBR  1980.0   W        MH
# 69290              Auto Buniks         POL  1988.0   W       MJA
# 69574                      NaN         SWE     NaN   W        MH
# 69640              Nacho Sport         ESP  1963.0   M       W40
# 69739                      NaN         GBR  1982.0   M        WH
# 80021                      NaN         GBR  1975.0   W       M30
# 80944                      NaN         DNK  1960.0   W       M45
# 86445                      NaN         FRA  1968.0   M       W35
# 86616   Wilde Wölfe Holzweißig         DEU  1956.0   W       M50
# 89023                      NaN         DEU  1970.0   W       M35
# 92208                      NaN         DEU  1988.0   M       WJA
# 96128                      NaN         FRA  1964.0   W       M40
# 99806                      NaN         BRA  1980.0   M        WH
# 102182                 Himanka         FIN  1959.0   M       W45
# 112288                     NaN         ITA  1969.0   M       W35
# 120566      BSG Deutscher Ring         DEU  1969.0   W       M35
# 124007                     NaN         DEU  1969.0   W       M35
# 124745                     NaN         DEU  1976.0   M       W35
# 126245                     NaN         NLD  1979.0   W        MH
#
#         age_class_place net_time clock_time  year   age
# 9201                353 03:06:49   03:07:37  2005  41.0
# 10108              3067 04:04:49   04:08:49  2005  43.0
# 19935              2410 03:54:04   03:56:47  2005  42.0
# 20122              1085 03:41:07   03:44:33  2005  48.0
# 23362              2017 03:47:41   03:49:22  2005  40.0
# 26631               840 04:33:09   04:37:12  2005  56.0
# 30198               102 03:38:31   03:40:10  2005  38.0
# 30200               677 04:26:27   04:30:40  2005  40.0
# 34335               495 03:16:09   03:16:17  2006  40.0
# 44551                 3 02:38:57   02:39:04  2006  45.0
# 58571               460 04:31:24   04:33:18  2006  49.0
# 60290                 5 03:11:03   03:11:27  2006  60.0
# 60849              3192 04:13:29   04:14:52  2007  37.0
# 63342              3830 04:35:38   04:36:56  2007  38.0
# 66246              1914 03:52:12   03:55:13  2007  46.0
# 66879               357 03:18:26   03:19:08  2007  27.0
# 69290               119 05:54:43   05:56:55  2007  19.0
# 69574              2558 05:03:28   05:04:51  2007   NaN
# 69640                58 03:26:09   03:28:44  2007  44.0
# 69739               549 04:32:42   04:33:03  2007  25.0
# 80021              1733 03:58:57   04:02:33  2007  32.0
# 80944               159 03:01:18   03:02:26  2007  47.0
# 86445               129 03:41:50   03:42:01  2007  39.0
# 86616              2290 04:40:06   04:42:31  2007  51.0
# 89023              4116 04:52:41   04:54:15  2007  37.0
# 92208                10 04:15:58   04:17:41  2007  19.0
# 96128              1082 03:22:29   03:22:55  2008  44.0
# 99806               258 03:56:58   04:01:31  2008  28.0
# 102182              589 04:22:10   04:24:49  2008  49.0
# 112288              283 03:55:55   03:58:28  2008  39.0
# 120566             3402 04:19:17   04:21:33  2008  39.0
# 124007              981 03:22:37   03:24:11  2008  39.0
# 124745             2725 03:59:50   04:14:42  2008  32.0
# 126245             2859 05:20:02   05:24:52  2008  29.0

# %% [markdown]
# Judging by the names, the real sex is usually in the age class.

# %%
inconsistent_sex.sex = inconsistent_sex.age_class.str.get(0)
inconsistent_sex
# Out:
#            id  place    bib      surname           forename  \
# 9201    10341   1532  F3923      Lohmann             Henrik
# 10108   11280  14344  F5717      Sanchez               Raul
# 19935   23704  10930  F4420      Kachlik            Stephan
# 20122   23897   7434  F5646    Kirchhoff             Jochen
# 23362   28829   9129  F6506         Pape             Gerald
# 26631   33336  21772  F8928     Tricoche          Elisabeth
# 30198   37786   6827  32681      Filippo           Proietti
# 30200   37789  20204  32699     Demetrio            Alberto
# 34335    4614   2110  F3676         Aeby     Pascal Laurent
# 44551   16028    106  F7055    Nordgaard            Haavard
# 58571   41938  19813  32282        Filho           Lourival
# 60290   43722   1571  F7523     Basdekis             Pavlos
# 60849     306  19484  F9642        Liden             Mikael
# 63342    2922  25182  F9645       Knaack             Oliver
# 66246    5922  12248  F2071  Himmelstein                Ari
# 66879    6571   3335  F9637       Holmes                Ben
# 69290    9038  32171  F9640     Wrzesien             Szymon
# 69574    9330  29549  F9643    Bergström            Fredrik
# 69640    9396   4775  33909  Ángel Ávila        Juan Manuel
# 69739    9497  24573  34121         Hyde               Kyle
# 80021   20252  15106  F9646      Eastman             Oliver
# 80944   21219   1270  F8957     Sørensen  Jytte Vestergaard
# 86445   29757   8923  34146        Frank         Vandenhole
# 86616   29964  26057  F9638      Richter              Frank
# 89023   33174  28164  F9639       Welber               Adam
# 92208   37911  20212    NaN      Middeke             Jasmin
# 96128    3667   4703  F1025       Maison             Sylvie
# 99806    7472  15536  37917       Macedo          Guilherme
# 102182   9951  23810  12454     Hautamaa               Anne
# 112288  20854  15085  37913      Michele              Tolin
# 120566  31461  22967  F5968      Morlang               René
# 124007  36818   4724  F7099        Rogoz           Grzegorz
# 124745  38362  16994  24442      Neuhaus             Svenja
# 126245  42364  33949  F9289      de Pape               Aldo
#
#                           team nationality     yob sex age_class  \
# 9201                    Sparta         DEN  1964.0   M       M40
# 10108                      NaN         SUI  1962.0   M       M40
# 19935                      NaN         GER  1963.0   M       M40
# 20122            TSV Bollensen         GER  1957.0   M       M45
# 23362       TriFrogs Gellersen         GER  1965.0   M       M40
# 26631             Defi Horizon         FRA  1949.0   M       M55
# 30198                      NaN         ITA  1967.0   W       W35
# 30200                      NaN         BRA  1965.0   W       W40
# 34335                      NaN         DEU  1966.0   M       M40
# 44551                     Nike         NOR  1961.0   M       M45
# 58571                   Brazil         BRA  1957.0   W       W45
# 60290                      NaN         GRC  1946.0   M       M60
# 60849                      NaN         SWE  1970.0   M       M35
# 63342     Berlin Sluggers e.V.         DEU  1969.0   M       M35
# 66246             The Team R&F         BRA  1961.0   M       M45
# 66879                      NaN         GBR  1980.0   M        MH
# 69290              Auto Buniks         POL  1988.0   M       MJA
# 69574                      NaN         SWE     NaN   M        MH
# 69640              Nacho Sport         ESP  1963.0   W       W40
# 69739                      NaN         GBR  1982.0   W        WH
# 80021                      NaN         GBR  1975.0   M       M30
# 80944                      NaN         DNK  1960.0   M       M45
# 86445                      NaN         FRA  1968.0   W       W35
# 86616   Wilde Wölfe Holzweißig         DEU  1956.0   M       M50
# 89023                      NaN         DEU  1970.0   M       M35
# 92208                      NaN         DEU  1988.0   W       WJA
# 96128                      NaN         FRA  1964.0   M       M40
# 99806                      NaN         BRA  1980.0   W        WH
# 102182                 Himanka         FIN  1959.0   W       W45
# 112288                     NaN         ITA  1969.0   W       W35
# 120566      BSG Deutscher Ring         DEU  1969.0   M       M35
# 124007                     NaN         DEU  1969.0   M       M35
# 124745                     NaN         DEU  1976.0   W       W35
# 126245                     NaN         NLD  1979.0   M        MH
#
#         age_class_place net_time clock_time  year   age
# 9201                353 03:06:49   03:07:37  2005  41.0
# 10108              3067 04:04:49   04:08:49  2005  43.0
# 19935              2410 03:54:04   03:56:47  2005  42.0
# 20122              1085 03:41:07   03:44:33  2005  48.0
# 23362              2017 03:47:41   03:49:22  2005  40.0
# 26631               840 04:33:09   04:37:12  2005  56.0
# 30198               102 03:38:31   03:40:10  2005  38.0
# 30200               677 04:26:27   04:30:40  2005  40.0
# 34335               495 03:16:09   03:16:17  2006  40.0
# 44551                 3 02:38:57   02:39:04  2006  45.0
# 58571               460 04:31:24   04:33:18  2006  49.0
# 60290                 5 03:11:03   03:11:27  2006  60.0
# 60849              3192 04:13:29   04:14:52  2007  37.0
# 63342              3830 04:35:38   04:36:56  2007  38.0
# 66246              1914 03:52:12   03:55:13  2007  46.0
# 66879               357 03:18:26   03:19:08  2007  27.0
# 69290               119 05:54:43   05:56:55  2007  19.0
# 69574              2558 05:03:28   05:04:51  2007   NaN
# 69640                58 03:26:09   03:28:44  2007  44.0
# 69739               549 04:32:42   04:33:03  2007  25.0
# 80021              1733 03:58:57   04:02:33  2007  32.0
# 80944               159 03:01:18   03:02:26  2007  47.0
# 86445               129 03:41:50   03:42:01  2007  39.0
# 86616              2290 04:40:06   04:42:31  2007  51.0
# 89023              4116 04:52:41   04:54:15  2007  37.0
# 92208                10 04:15:58   04:17:41  2007  19.0
# 96128              1082 03:22:29   03:22:55  2008  44.0
# 99806               258 03:56:58   04:01:31  2008  28.0
# 102182              589 04:22:10   04:24:49  2008  49.0
# 112288              283 03:55:55   03:58:28  2008  39.0
# 120566             3402 04:19:17   04:21:33  2008  39.0
# 124007              981 03:22:37   03:24:11  2008  39.0
# 124745             2725 03:59:50   04:14:42  2008  32.0
# 126245             2859 05:20:02   05:24:52  2008  29.0

# %%
inconsistent_sex.set_value(99806, 'sex', 'M')
inconsistent_sex.set_value(96128, 'sex', 'W')
inconsistent_sex.set_value(86445, 'sex', 'M')
inconsistent_sex.set_value(69640, 'sex', 'M')
inconsistent_sex.set_value(58571, 'sex', 'M')
inconsistent_sex.set_value(30200, 'sex', 'M')
inconsistent_sex.set_value(30198, 'sex', 'M')

df.loc[inconsistent_sex.index, 'sex'] = inconsistent_sex.sex
df.loc[inconsistent_sex.index, :]
# Out:
#            id  place    bib      surname           forename  \
# 9201    10341   1532  F3923      Lohmann             Henrik
# 10108   11280  14344  F5717      Sanchez               Raul
# 19935   23704  10930  F4420      Kachlik            Stephan
# 20122   23897   7434  F5646    Kirchhoff             Jochen
# 23362   28829   9129  F6506         Pape             Gerald
# 26631   33336  21772  F8928     Tricoche          Elisabeth
# 30198   37786   6827  32681      Filippo           Proietti
# 30200   37789  20204  32699     Demetrio            Alberto
# 34335    4614   2110  F3676         Aeby     Pascal Laurent
# 44551   16028    106  F7055    Nordgaard            Haavard
# 58571   41938  19813  32282        Filho           Lourival
# 60290   43722   1571  F7523     Basdekis             Pavlos
# 60849     306  19484  F9642        Liden             Mikael
# 63342    2922  25182  F9645       Knaack             Oliver
# 66246    5922  12248  F2071  Himmelstein                Ari
# 66879    6571   3335  F9637       Holmes                Ben
# 69290    9038  32171  F9640     Wrzesien             Szymon
# 69574    9330  29549  F9643    Bergström            Fredrik
# 69640    9396   4775  33909  Ángel Ávila        Juan Manuel
# 69739    9497  24573  34121         Hyde               Kyle
# 80021   20252  15106  F9646      Eastman             Oliver
# 80944   21219   1270  F8957     Sørensen  Jytte Vestergaard
# 86445   29757   8923  34146        Frank         Vandenhole
# 86616   29964  26057  F9638      Richter              Frank
# 89023   33174  28164  F9639       Welber               Adam
# 92208   37911  20212    NaN      Middeke             Jasmin
# 96128    3667   4703  F1025       Maison             Sylvie
# 99806    7472  15536  37917       Macedo          Guilherme
# 102182   9951  23810  12454     Hautamaa               Anne
# 112288  20854  15085  37913      Michele              Tolin
# 120566  31461  22967  F5968      Morlang               René
# 124007  36818   4724  F7099        Rogoz           Grzegorz
# 124745  38362  16994  24442      Neuhaus             Svenja
# 126245  42364  33949  F9289      de Pape               Aldo
#
#                           team nationality     yob sex age_class  \
# 9201                    Sparta         DEN  1964.0   M       M40
# 10108                      NaN         SUI  1962.0   M       M40
# 19935                      NaN         GER  1963.0   M       M40
# 20122            TSV Bollensen         GER  1957.0   M       M45
# 23362       TriFrogs Gellersen         GER  1965.0   M       M40
# 26631             Defi Horizon         FRA  1949.0   M       M55
# 30198                      NaN         ITA  1967.0   M       W35
# 30200                      NaN         BRA  1965.0   M       W40
# 34335                      NaN         DEU  1966.0   M       M40
# 44551                     Nike         NOR  1961.0   M       M45
# 58571                   Brazil         BRA  1957.0   M       W45
# 60290                      NaN         GRC  1946.0   M       M60
# 60849                      NaN         SWE  1970.0   M       M35
# 63342     Berlin Sluggers e.V.         DEU  1969.0   M       M35
# 66246             The Team R&F         BRA  1961.0   M       M45
# 66879                      NaN         GBR  1980.0   M        MH
# 69290              Auto Buniks         POL  1988.0   M       MJA
# 69574                      NaN         SWE     NaN   M        MH
# 69640              Nacho Sport         ESP  1963.0   M       W40
# 69739                      NaN         GBR  1982.0   W        WH
# 80021                      NaN         GBR  1975.0   M       M30
# 80944                      NaN         DNK  1960.0   M       M45
# 86445                      NaN         FRA  1968.0   M       W35
# 86616   Wilde Wölfe Holzweißig         DEU  1956.0   M       M50
# 89023                      NaN         DEU  1970.0   M       M35
# 92208                      NaN         DEU  1988.0   W       WJA
# 96128                      NaN         FRA  1964.0   W       M40
# 99806                      NaN         BRA  1980.0   M        WH
# 102182                 Himanka         FIN  1959.0   W       W45
# 112288                     NaN         ITA  1969.0   W       W35
# 120566      BSG Deutscher Ring         DEU  1969.0   M       M35
# 124007                     NaN         DEU  1969.0   M       M35
# 124745                     NaN         DEU  1976.0   W       W35
# 126245                     NaN         NLD  1979.0   M        MH
#
#         age_class_place net_time clock_time  year   age
# 9201                353 03:06:49   03:07:37  2005  41.0
# 10108              3067 04:04:49   04:08:49  2005  43.0
# 19935              2410 03:54:04   03:56:47  2005  42.0
# 20122              1085 03:41:07   03:44:33  2005  48.0
# 23362              2017 03:47:41   03:49:22  2005  40.0
# 26631               840 04:33:09   04:37:12  2005  56.0
# 30198               102 03:38:31   03:40:10  2005  38.0
# 30200               677 04:26:27   04:30:40  2005  40.0
# 34335               495 03:16:09   03:16:17  2006  40.0
# 44551                 3 02:38:57   02:39:04  2006  45.0
# 58571               460 04:31:24   04:33:18  2006  49.0
# 60290                 5 03:11:03   03:11:27  2006  60.0
# 60849              3192 04:13:29   04:14:52  2007  37.0
# 63342              3830 04:35:38   04:36:56  2007  38.0
# 66246              1914 03:52:12   03:55:13  2007  46.0
# 66879               357 03:18:26   03:19:08  2007  27.0
# 69290               119 05:54:43   05:56:55  2007  19.0
# 69574              2558 05:03:28   05:04:51  2007   NaN
# 69640                58 03:26:09   03:28:44  2007  44.0
# 69739               549 04:32:42   04:33:03  2007  25.0
# 80021              1733 03:58:57   04:02:33  2007  32.0
# 80944               159 03:01:18   03:02:26  2007  47.0
# 86445               129 03:41:50   03:42:01  2007  39.0
# 86616              2290 04:40:06   04:42:31  2007  51.0
# 89023              4116 04:52:41   04:54:15  2007  37.0
# 92208                10 04:15:58   04:17:41  2007  19.0
# 96128              1082 03:22:29   03:22:55  2008  44.0
# 99806               258 03:56:58   04:01:31  2008  28.0
# 102182              589 04:22:10   04:24:49  2008  49.0
# 112288              283 03:55:55   03:58:28  2008  39.0
# 120566             3402 04:19:17   04:21:33  2008  39.0
# 124007              981 03:22:37   03:24:11  2008  39.0
# 124745             2725 03:59:50   04:14:42  2008  32.0
# 126245             2859 05:20:02   05:24:52  2008  29.0

# %%
df.age_class = df.age_class.str.replace(r'[MW]?(.*)', r'\1')
df.age_class.value_counts().sort_index()
# Out:
#           33
# 30     49169
# 35     63148
# 40     80798
# 45     73169
# 50     50221
# 55     24577
# 60     11421
# 65      4786
# 70      1618
# 75       340
# 80        57
# H      42355
# JA      1318
# U20       95
# Name: age_class, dtype: int64

# %%
len(df[(df.age_class == "")])
# Out:
# 33

# %%
df.age_class = df.age_class.replace('', np.nan)
len(df[df.age_class == ""])
# Out:
# 0

# %%
df.groupby('age_class').age.aggregate(['min', 'max'])
# Out:
#             min   max
# age_class
# 30         30.0  54.0
# 35         32.0  40.0
# 40         39.0  44.0
# 45         45.0  49.0
# 50         47.0  54.0
# 55         55.0  59.0
# 60         60.0  64.0
# 65         65.0  69.0
# 70         60.0  74.0
# 75         75.0  79.0
# 80         80.0  86.0
# H          20.0  48.0
# JA         14.0  19.0
# U20        18.0  19.0

# %%
df[(df.age_class == '30') & (df.age >= 35)]
# Out:
#            id  place    bib surname forename             team nationality  \
# 122666  34733   4928  36826   Silva    Usiel  Rho Delta Trave         BRA
#
#            yob sex age_class  age_class_place net_time clock_time  year   age
# 122666  1954.0   M        30              677 03:23:32   03:23:38  2008  54.0

# %%
df.set_value(122666, 'age_class', '50')

df[(df.age_class == '35') & (df.age < 35)]
# Out:
#            id  place    bib  surname forename team nationality     yob sex  \
# 124745  38362  16994  24442  Neuhaus   Svenja  NaN         DEU  1976.0   W
#
#        age_class  age_class_place net_time clock_time  year   age
# 124745        35             2725 03:59:50   04:14:42  2008  32.0

# %%
df.set_value(124745, 'age_class', '30')

df[(df.age_class == '50') & (df.age < 50)]
# Out:
#            id  place    bib      surname   forename team nationality     yob  \
# 101200   8907   2532  17349       Lameir  Christian  NaN         DEU  1959.0
# 261808  32192  20225  13846  Hundertmark      Peter  NaN         DEU  1965.0
#
#        sex age_class  age_class_place net_time clock_time  year   age
# 101200   M        50              155 03:10:18   03:10:26  2008  49.0
# 261808   M        50             2125 04:12:00   04:22:19  2012  47.0

# %%
df.set_value(261808, 'age_class', '45')

df[(df.age_class == '70') & (df.age < 70)]
# Out:
#            id  place    bib   surname forename      team nationality     yob  \
# 144135  16097  28932   F174  Kiederle    Inger  Atletica         DNK  1942.0
# 160277  32876  20390  37361     Thiel    Peter       NaN         DEU  1949.0
#
#        sex age_class  age_class_place net_time clock_time  year   age
# 144135   W        70                3 04:52:07   05:07:35  2009  67.0
# 160277   M        70               19 04:19:01   04:30:43  2009  60.0

# %%
df.set_value(144135, 'age_class', '65')
df.set_value(160277, 'age_class', '60')

df[(df.age_class == 'H') & (df.age >= 30)]
# Out:
#            id  place    bib   surname   forename                team  \
# 81816   22121     41     84    Güssow  Christian        Hamburger SV
# 147825  19946  14485  23852  Pranzner    Andreas  Berliner Feuerwehr
#
#        nationality     yob sex age_class  age_class_place net_time clock_time  \
# 81816          DEU  1976.0   M         H               17 02:27:05   02:27:08
# 147825         DEU  1961.0   M         H             1415 04:00:00   04:19:35
#
#         year   age
# 81816   2007  31.0
# 147825  2009  48.0

# %%
df.set_value(81816, 'age_class', '30')
df.set_value(147825, 'age_class', '45')

def upper(match):
    if match.group(2) == '0':
        d = '4'
    else:
        d = '9'
    return '{0}-{1}{2}'.format(match.group(0), match.group(1), d)

df.age_class = df.age_class.str.replace(r'^(JA|U20)$', '0-19').str.replace('^H$', '20-29').str.replace(r'^8.*', '80+').str.replace(r'^(\d)(\d)$', upper)
df.groupby('age_class').age.aggregate(['min', 'max'])
# Out:
#             min   max
# age_class
# 0-19       14.0  19.0
# 20-29      20.0  29.0
# 30-34      30.0  34.0
# 35-39      35.0  40.0
# 40-44      39.0  44.0
# 45-49      45.0  49.0
# 50-54      49.0  54.0
# 55-59      55.0  59.0
# 60-64      60.0  64.0
# 65-69      65.0  69.0
# 70-74      70.0  74.0
# 75-79      75.0  79.0
# 80+        80.0  86.0

# %%
age_classes = pd.unique(df.age_class.dropna())
df.age_class = df.age_class.astype('category', categories=age_classes, ordered=True)

# %% [markdown]
# ## Age Class Place

# %%
df.age_class_place.describe()
# Out:
# count    403134.000000
# mean       1596.684058
# std        1321.932040
# min           0.000000
# 25%         517.000000
# 50%        1208.000000
# 75%        2456.000000
# max        6101.000000
# Name: age_class_place, dtype: float64

# %%
len(df[df.age_class_place.isnull()])
# Out:
# 0

# %%
df.age_class_place = df.age_class_place.replace(0, np.nan)
yob_no_ac = df[(df.age_class_place.isnull()) & (~df.yob.isnull())]
yob_no_ac.age_class = (5 * (yob_no_ac.age // 5)).astype('int').astype('str').str.replace(r'^(\d)(\d)$', upper).astype('category', categories=age_classes)
yob_no_ac
# Out:
# /home/brian/.virtualenvs/generic/lib/python3.5/site-packages/pandas/core/generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
#             id  place     bib        surname     forename  \
# 177069   13887   9534     NaN           Coll      Florian
# 250216   20259  12554    3612     Adriaansen         Dave
# 256755   26984   6633    1600  Van Den Bergh       Dennis
# 354959   93204   3633   38826        Hofmann         Lars
# 357198  101622     20     100        Solomon  Tesfamariam
# 367138  141090  36483  F12454         Stasch      Christa
# 367139  141108  35431   38838           Wang    Hsi-Tsang
# 367140  141111   9428   38825      Heinrichs       Markus
# 367141  141114  19328   38827           Huai    Qianjiang
# 367142  141120  18143   38828          Kraus       Martin
#
#                          team nationality     yob sex age_class  \
# 177069           Cours Forest         FRA  1983.0   M       NaN
# 250216                    NaN         NLD  1977.0   M     35-39
# 256755                    NaN         DEU  1969.0   M     40-44
# 354959       Tv Großen Buseck         GER  1979.0   M     35-39
# 357198               TVL Bern         ERI  1976.0   M     35-39
# 367138                    NaN         GER  1956.0   W     55-59
# 367139                    NaN         TPE  1976.0   M     35-39
# 367140  SCW München Triathlon         GER  1980.0   M     35-39
# 367141                    NaN         CHN  1975.0   M     40-44
# 367142                    NaN         GER  1975.0   M     40-44
#
#         age_class_place net_time clock_time  year   age
# 177069              NaN 03:41:07   03:52:11  2010  27.0
# 250216              NaN 03:49:46   04:00:05  2012  35.0
# 256755              NaN 03:29:36   03:35:05  2012  43.0
# 354959              NaN 03:13:33   03:14:14  2015  36.0
# 357198              NaN 02:14:51   02:14:51  2015  39.0
# 367138              NaN 06:10:32   06:46:46  2015  59.0
# 367139              NaN 05:36:47   06:16:10  2015  39.0
# 367140              NaN 03:36:51   03:56:07  2015  35.0
# 367141              NaN 04:04:35   04:24:01  2015  40.0
# 367142              NaN 04:00:32   04:23:56  2015  40.0

# %%
df.loc[yob_no_ac.index, 'age_class'] = yob_no_ac.age_class

# %% [markdown]
# ## Teams

# %%
df.team.describe()
# Out:
# count       181573
# unique       68777
# top       Terramia
# freq          1908
# Name: team, dtype: object

# %% [markdown]
# ## Nationality

# %%
df.nationality.describe()
# Out:
# count     403120
# unique       250
# top          DEU
# freq      155501
# Name: nationality, dtype: object

# %%
len(df[df.nationality.isnull()])
# Out:
# 14

# %% [markdown]
# [ISO](https://en.wikipedia.org/wiki/ISO_3166-1)
# [FIFA](https://en.wikipedia.org/wiki/List_of_FIFA_country_codes)
# [IOC](https://en.wikipedia.org/wiki/List_of_IOC_country_codes)

# %%
nat = pd.read_csv('../data/countries.csv')
nat.head()
# Out:
#   abbreviation iso3166_1alpha_3               country
# 0          ABW              ABW                 Aruba
# 1          AFG              AFG           Afghanistan
# 2          AGO              AGO                Angola
# 3          AHO              AHO  Netherlands Antilles
# 4          ALB              ALB               Albania

# %%
sorted(set(df.nationality.dropna()) - set(nat.abbreviation))
# Out:
# ['RKS']

# %%
dfnat = pd.merge(df, nat, left_on='nationality', right_on='abbreviation', how='left').sort_values(['year', 'id']) #.reindex(df.index)
(df.index == dfnat.index).min()
# Out:
# True

# %%
df.nationality = dfnat.iso3166_1alpha_3
df.nationality.describe()
# Out:
# count     403117
# unique       199
# top          DEU
# freq      192234
# Name: nationality, dtype: object

# %% [markdown]
# ## Names

# %%
df.forename.describe()
# Out:
# count     403089
# unique     37436
# top       Thomas
# freq        7865
# Name: forename, dtype: object

# %%
len(df[df.forename.isnull()])
# Out:
# 45

# %%
df[(df.forename.isnull()) & (~df.surname.isnull())]
# Out:
#            id  place    bib                             surname forename  \
# 60554   44151  15749  29772  Chávez-Fernández Goyburu,Juan José      NaN
# 60901     359  31004  F1115                          Mackenzie,      NaN
# 94924    2386  22570  F2721                   Elvers-Schreiber,      NaN
# 122234  34063  17214  F2727            Emmanuelle Rochet-Blanc,      NaN
# 124378  37491  34879  37896                           Williams,      NaN
# 124379  37492  27883  37897                              Keith,      NaN
# 125273  39885   4790  37898                           Witfield,      NaN
# 132211   3741    836   6092                             Bosgoed      NaN
# 266361   1602   6254  10087                              Gestin      NaN
#
#                           team nationality     yob sex age_class  \
# 60554             Regatas Lima         PER  1967.0   M     35-39
# 60901                      NaN         NLD  1962.0   W     45-49
# 94924               DAV Berlin         DEU  1951.0   W     55-59
# 122234  les chauffe la semelle         FRA  1968.0   W     40-44
# 124378                     NaN         DEU     NaN   M     20-29
# 124379                     NaN         GBR     NaN   M     20-29
# 125273                     NaN         GBR     NaN   M     20-29
# 132211                  ARO'88         NLD  1966.0   M     40-44
# 266361         CACL Courbevoie         FRA  1967.0   M     45-49
#
#         age_class_place net_time clock_time  year   age
# 60554            2771.0 04:15:47   04:18:00  2006  39.0
# 60901            1028.0 05:21:45   05:29:38  2007  45.0
# 94924              86.0 04:17:47   04:22:01  2008  57.0
# 122234            433.0 04:00:22   04:06:18  2008  40.0
# 124378           2921.0 05:38:09   05:44:09  2008   NaN
# 124379           2452.0 04:37:34   04:41:15  2008   NaN
# 125273            503.0 03:22:56   03:24:39  2008   NaN
# 132211            183.0 02:57:05   02:57:29  2009  43.0
# 266361           1086.0 03:27:16   03:30:36  2013  46.0

# %%
df.set_value(60554, 'forename', 'Juan José')
df.set_value(60554, 'surname', 'Chávez-Fernández Goyburu')

df.surname.describe()
# Out:
# count      403096
# unique     127265
# top       Nielsen
# freq         1648
# Name: surname, dtype: object

# %%
len(df[df.surname.isnull()])
# Out:
# 38

# %%
df[(df.surname.isnull()) & (~df.forename.isnull())]
# Out:
#            id  place    bib surname   forename                team  \
# 30385      16  12730  32232     NaN   Benjamin                 NaN
# 148108  20236    223  26347     NaN  Christoph  LAV Asics Tübingen
#
#        nationality     yob sex age_class  age_class_place net_time clock_time  \
# 30385          DEU  1982.0   M     20-29           1134.0 04:04:33   04:10:01
# 148108         DEU  1984.0   M     20-29             53.0 02:41:58   02:42:06
#
#         year   age
# 30385   2006  24.0
# 148108  2009  25.0

# %%
df.surname = df.surname.str.strip(string.punctuation)
df.forename = df.forename.str.strip(string.punctuation)

# %% [markdown]
# ## Bibs

# %%
df.bib.describe()
# Out:
# count     403127
# unique     59339
# top        F1024
# freq          37
# Name: bib, dtype: object

# %%
len(df[df.bib.isnull()])
# Out:
# 7

# %% [markdown]
# ## Save the Clean Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403134 entries, 0 to 403133
# Data columns (total 15 columns):
# id                 403134 non-null int64
# place              403134 non-null int64
# bib                403127 non-null object
# surname            403096 non-null object
# forename           403090 non-null object
# team               181573 non-null object
# nationality        403117 non-null object
# yob                402885 non-null float64
# sex                403134 non-null category
# age_class          403078 non-null category
# age_class_place    403071 non-null float64
# net_time           403132 non-null timedelta64[ns]
# clock_time         403128 non-null timedelta64[ns]
# year               403134 non-null int64
# age                402885 non-null float64
# dtypes: category(2), float64(3), int64(3), object(5), timedelta64[ns](2)
# memory usage: 40.8+ MB

# %%
df.net_time = df.net_time.astype(str).str.split().str[-1].str.rsplit('.').str[0]
df.clock_time = df.clock_time.astype(str).str.split().str[-1].str.rsplit('.').str[0]

df.sort_values(['year', 'id']).to_csv(clean_filename, index=True, index_label='idx')

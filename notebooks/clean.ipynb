# %% [markdown]
# # Cleaning the Dataset

# %% [markdown]
# ## Setup

# %%
import sys
sys.path.append('..')

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
import json
import os.path
import string
from scripts.scrape import get_json, get_metadata

# %%
data_folder = os.path.join('..', 'data')

dirty_filename = os.path.join(data_folder, 'berlin_marathon_times_dirty.csv')
clean_filename = os.path.join(data_folder, 'berlin_marathon_times.csv')

dirty_filename
# Out:
# '../data/berlin_marathon_times_dirty.csv'

# %%
df = pd.read_csv(dirty_filename)
df.head()
# Out:
#    id  place    bib        surname     forename                  team  \
# 0   2  19431   2002    Ohnemueller  Bert Martin                   NaN
# 1   3  10609  29356     Klinginger         Kurt    smart running team
# 2   4  23031   2034  Eleftheriadis     Georgios                   NaN
# 3   5  14104   2035         Scholz       Detlef                   NaN
# 4   6  30239   F105       Frischke        Lucie  LAV Tempelhof Berlin
#
#   nationality   yob sex age_class  age_class_place  net_time clock_time  year
# 0         GER  1959   M       M45             2758  04:23:26   04:23:48  2005
# 1         GER  1947   M       M55              344  03:53:01   03:56:43  2005
# 2         GRE  1962   M       M40             4470  04:38:47   04:42:41  2005
# 3         GER  1970   M       M35             2573  04:03:50   04:05:14  2005
# 4         GER  1932   W       W70                2  06:07:10   06:09:04  2005

# %% [markdown]
# ## Completeness Check

# %%
participants_year = df.year.value_counts().sort_index()
participants_year
# Out:
# 2005    30373
# 2006    30182
# 2007    32486
# 2008    35731
# 2009    35015
# 2010    34001
# 2011    32914
# 2012    34270
# 2013    36473
# 2014    28945
# 2015    36753
# 2016    35991
# Name: year, dtype: int64

# %%
participants_year_meta = participants_year.copy()

for year in participants_year.index:
    with open('../data/{0}-1.json'.format(year)) as f:
        j = json.load(f)
        m = get_metadata(j)
        participants_year_meta[year] = m.n_rows
        
participants_year_meta
# Out:
# 2005    30373
# 2006    30182
# 2007    32486
# 2008    35731
# 2009    35015
# 2010    34001
# 2011    32914
# 2012    34270
# 2013    36473
# 2014    28945
# 2015    36753
# 2016    35991
# Name: year, dtype: int64

# %%
len(participants_year[participants_year != participants_year_meta])
# Out:
# 0

# %% [markdown]
# ## Overview

# %%
len(df)
# Out:
# 403134

# %%
df.dtypes
# Out:
# id                  int64
# place               int64
# bib                object
# surname            object
# forename           object
# team               object
# nationality        object
# yob                 int64
# sex                object
# age_class          object
# age_class_place     int64
# net_time           object
# clock_time         object
# year                int64
# dtype: object

# %%
df.describe()
# Out:
#                   id          place            yob  age_class_place  \
# count  403134.000000  403134.000000  403134.000000    403134.000000
# mean    26240.607041   16899.358593    1967.243013      1596.684058
# std     25441.663187    9861.602089      47.518969      1321.932040
# min         2.000000       1.000000       0.000000         0.000000
# 25%     10150.000000    8402.000000    1962.000000       517.000000
# 50%     20216.000000   16804.000000    1968.000000      1208.000000
# 75%     31350.000000   25206.000000    1976.000000      2456.000000
# max    141120.000000   36768.000000    1998.000000      6101.000000
#
#                 year
# count  403134.000000
# mean     2010.619734
# std         3.426661
# min      2005.000000
# 25%      2008.000000
# 50%      2011.000000
# 75%      2014.000000
# max      2016.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403134 entries, 0 to 403133
# Data columns (total 14 columns):
# id                 403134 non-null int64
# place              403134 non-null int64
# bib                403127 non-null object
# surname            403096 non-null object
# forename           403089 non-null object
# team               181573 non-null object
# nationality        403120 non-null object
# yob                403134 non-null int64
# sex                403132 non-null object
# age_class          403105 non-null object
# age_class_place    403134 non-null int64
# net_time           403134 non-null object
# clock_time         403134 non-null object
# year               403134 non-null int64
# dtypes: int64(5), object(9)
# memory usage: 43.1+ MB

# %% [markdown]
# # Unique IDs

# %%
id_counts = df.groupby('id').year.count()
id_problems = id_counts[id_counts > 1]
len(id_problems)
# Out:
# 58616

# %%
id_problems.describe()
# Out:
# count    58616.000000
# mean         6.602378
# std          3.688039
# min          2.000000
# 25%          2.000000
# 50%          8.000000
# 75%         10.000000
# max         12.000000
# Name: year, dtype: float64

# %%
ids = df.groupby(['id', 'year']).place.count()
ids_problems = ids[ids > 1]
len(ids_problems)
# Out:
# 0

# %%
df.id = (df.year.astype('str') + df.id.astype('str')).astype('int64')
df.head()
# Out:
#       id  place    bib        surname     forename                  team  \
# 0  20052  19431   2002    Ohnemueller  Bert Martin                   NaN
# 1  20053  10609  29356     Klinginger         Kurt    smart running team
# 2  20054  23031   2034  Eleftheriadis     Georgios                   NaN
# 3  20055  14104   2035         Scholz       Detlef                   NaN
# 4  20056  30239   F105       Frischke        Lucie  LAV Tempelhof Berlin
#
#   nationality   yob sex age_class  age_class_place  net_time clock_time  year
# 0         GER  1959   M       M45             2758  04:23:26   04:23:48  2005
# 1         GER  1947   M       M55              344  03:53:01   03:56:43  2005
# 2         GRE  1962   M       M40             4470  04:38:47   04:42:41  2005
# 3         GER  1970   M       M35             2573  04:03:50   04:05:14  2005
# 4         GER  1932   W       W70                2  06:07:10   06:09:04  2005

# %%
id_counts = df.groupby('id').year.count()
id_problems = id_counts[id_counts > 1]
len(id_problems)
# Out:
# 0

# %%
df = df.set_index('id')

# %% [markdown]
# ## Place

# %%
len(df[df.place.isnull()])
# Out:
# 0

# %%
df.place.describe()
# Out:
# count    403134.000000
# mean      16899.358593
# std        9861.602089
# min           1.000000
# 25%        8402.000000
# 50%       16804.000000
# 75%       25206.000000
# max       36768.000000
# Name: place, dtype: float64

# %% [markdown]
# ## Times

# %%
len(df[df.net_time.isnull()])
# Out:
# 0

# %%
len(df[df.clock_time.isnull()])
# Out:
# 0

# %%
df.net_time = pd.to_timedelta(df.net_time)
df.clock_time = pd.to_timedelta(df.clock_time)
df.head()
# Out:
#        place    bib        surname     forename                  team  \
# id
# 20052  19431   2002    Ohnemueller  Bert Martin                   NaN
# 20053  10609  29356     Klinginger         Kurt    smart running team
# 20054  23031   2034  Eleftheriadis     Georgios                   NaN
# 20055  14104   2035         Scholz       Detlef                   NaN
# 20056  30239   F105       Frischke        Lucie  LAV Tempelhof Berlin
#
#       nationality   yob sex age_class  age_class_place net_time clock_time  \
# id
# 20052         GER  1959   M       M45             2758 04:23:26   04:23:48
# 20053         GER  1947   M       M55              344 03:53:01   03:56:43
# 20054         GRE  1962   M       M40             4470 04:38:47   04:42:41
# 20055         GER  1970   M       M35             2573 04:03:50   04:05:14
# 20056         GER  1932   W       W70                2 06:07:10   06:09:04
#
#        year
# id
# 20052  2005
# 20053  2005
# 20054  2005
# 20055  2005
# 20056  2005

# %%
df.net_time.describe()
# Out:
# count                    403134
# mean     0 days 04:09:00.199402
# std      0 days 00:42:32.086175
# min             0 days 00:00:00
# 25%             0 days 03:39:12
# 50%             0 days 04:04:23
# 75%             0 days 04:35:43
# max             0 days 08:41:33
# Name: net_time, dtype: object

# %%
df.clock_time.describe()
# Out:
# count                    403134
# mean     0 days 04:19:57.418917
# std      0 days 00:48:21.491980
# min             0 days 00:00:00
# 25%             0 days 03:45:24
# 50%             0 days 04:16:00
# 75%      0 days 04:51:08.750000
# max             0 days 11:01:11
# Name: clock_time, dtype: object

# %% [markdown]
# The maximum times are above the 6 hour cutoff.

# %%
zero = pd.Timedelta(0)
len(df[df.net_time == zero])
# Out:
# 2

# %%
df.net_time = df.net_time.replace(zero, np.nan)
len(df[df.net_time == zero])
# Out:
# 0

# %%
zero_clock_times = df[df.clock_time == zero]
zero_clock_times
# Out:
#            place    bib   surname forename                            team  \
# id
# 20132212   31946   WF33     Power  Patrice                             NaN
# 201313031  28509   WF25  Meissner   Sabine  SV Turbine Neubrandenburg, Wal
# 201334468  28563  34343   Oltmans     Egon                             NaN
# 201429961  17446  32000    Müller    Heino                             NaN
# 201519713   9277  39035    Fennel   Sascha                             NaN
# 201579851   2783  39046   Schmidt  Andreas                             NaN
#
#           nationality   yob sex age_class  age_class_place net_time  \
# id
# 20132212          IRL  1964   W        45             1372 04:53:26
# 201313031         DEU  1959   W        50              717 04:35:28
# 201334468         NLD  1960   M        50             3122      NaT
# 201429961         DEU  1953   M        60              300 04:14:04
# 201519713         GER  1964   M        50              879 03:36:20
# 201579851         GER  1973   M        40              585 03:08:17
#
#           clock_time  year
# id
# 20132212      0 days  2013
# 201313031     0 days  2013
# 201334468     0 days  2013
# 201429961     0 days  2014
# 201519713     0 days  2015
# 201579851     0 days  2015

# %%
df.clock_time = df.clock_time.replace(zero, np.nan)
len(df[df.clock_time == zero])
# Out:
# 0

# %%
times = df[df.net_time > df.clock_time]
times
# Out:
#            place    bib   surname forename                     team  \
# id
# 200641853  22138  F4217     Vogel   Esther                      NaN
# 201411182   2673  13549  Sowisnki  Fabrice  SAINT VENANT ATHLETISME
#
#           nationality   yob sex age_class  age_class_place net_time  \
# id
# 200641853         DEU  1973   W       W30              524 04:41:51
# 201411182         FRA  1974   M        40              595 03:13:55
#
#           clock_time  year
# id
# 200641853   04:26:20  2006
# 201411182   02:58:59  2014

# %%
ev = df.loc[200641853]
fs = df.loc[201411182]

# %%
df[(df.year == ev.year) & (ev.place - 5 < df.place) & (df.place < ev.place + 5)].sort_values('place')
# Out:
#            place    bib     surname     forename             team nationality  \
# id
# 20063560   22134  18419       Arens         Marc     KJG Mü/Si/Wa         DEU
# 20069778   22135  12254   von Blume         Marc  SV Blitzenreute         DEU
# 200613258  22136   8523       Kolke     Reinhard              NaN         DEU
# 200626030  22137  26910  Wojczewski  Axel-Rainer              NaN         DEU
# 200617899  22138  F3482       Lorch       Renate              NaN         DEU
# 200641853  22138  F4217       Vogel       Esther              NaN         DEU
# 200614787  22140  16772      Kaspar       Werner              NaN         DEU
# 200643398  22141  13745      Ruholl        Steve              NaN         DEU
# 200628360  22142  29253     Fortune  Jean Pierre              NaN         FRA
#
#             yob sex age_class  age_class_place net_time clock_time  year
# id
# 20063560   1984   M        MH             1816 04:41:50   04:43:58  2006
# 20069778   1962   M       M40             4357 04:41:50   04:43:48  2006
# 200613258  1968   M       M35             3544 04:41:50   04:43:41  2006
# 200626030  1949   M       M55              936 04:41:51   04:46:29  2006
# 200617899  1960   W       W45              579 04:41:51   04:47:42  2006
# 200641853  1973   W       W30              524 04:41:51   04:26:20  2006
# 200614787  1953   M       M50             1985 04:41:52   04:45:27  2006
# 200643398  1979   M        MH             1817 04:41:52   04:45:31  2006
# 200628360  1955   M       M50             1986 04:41:52   04:46:23  2006

# %%
df.set_value(ev.name, 'clock_time', ev.clock_time + pd.Timedelta('20 min'))
df.loc[ev.name]
# Out:
# place                        22138
# bib                          F4217
# surname                      Vogel
# forename                    Esther
# team                           NaN
# nationality                    DEU
# yob                           1973
# sex                              W
# age_class                      W30
# age_class_place                524
# net_time           0 days 04:41:51
# clock_time         0 days 04:46:20
# year                          2006
# Name: 200641853, dtype: object

# %%
df[(df.year == fs.year) & (fs.place - 5 < df.place) & (df.place < fs.place + 5)].sort_values('place')
# Out:
#            place    bib     surname forename                     team  \
# id
# 201428140   2669  24681     Rousing    Allan                      MTC
# 20143965    2670   6318       Borck      Jan          Der Kleine Muck
# 20146920    2671  26033    Schuller    Eelco                      PAC
# 201428776   2672   6185        Boge    Georg                      NaN
# 201411182   2673  13549    Sowisnki  Fabrice  SAINT VENANT ATHLETISME
# 20144960    2674   F597    Aljancic   Natasa               AK DOMALE
# 20143080    2675   7519    Chambers     Dion                      NaN
# 20145671    2676   7933     Colsman  Philipp                      NaN
# 201426721   2677  13784  Hinrichsen   Thomas               HRLK / BLL
#
#           nationality   yob sex age_class  age_class_place net_time  \
# id
# 201428140         DNK  1969   M        45              441 03:13:55
# 20143965          DEU  1964   M        50              200 03:13:55
# 20146920          NLD  1986   M         H              264 03:13:55
# 201428776         DEU  1980   M        30              464 03:13:55
# 201411182         FRA  1974   M        40              595 03:13:55
# 20144960          SVN  1969   W        45               13 03:13:56
# 20143080          GBR  1989   M         H              265 03:13:56
# 20145671          DEU  1967   M        45              442 03:13:57
# 201426721         DNK  1975   M        35              517 03:13:58
#
#           clock_time  year
# id
# 201428140   03:18:26  2014
# 20143965    03:14:12  2014
# 20146920    03:15:41  2014
# 201428776   03:18:29  2014
# 201411182   02:58:59  2014
# 20144960    03:15:45  2014
# 20143080    03:14:53  2014
# 20145671    03:16:41  2014
# 201426721   03:14:12  2014

# %%
df.set_value(fs.name, 'clock_time', ev.clock_time + pd.Timedelta('20 min'))
df.loc[fs.name]
# Out:
# place                                 2673
# bib                                  13549
# surname                           Sowisnki
# forename                           Fabrice
# team               SAINT VENANT ATHLETISME
# nationality                            FRA
# yob                                   1974
# sex                                      M
# age_class                               40
# age_class_place                        595
# net_time                   0 days 03:13:55
# clock_time                 0 days 04:46:20
# year                                  2014
# Name: 201411182, dtype: object

# %%
len(df[df.net_time > df.clock_time])
# Out:
# 0

# %% [markdown]
# ## Sex

# %%
df.sex.describe()
# Out:
# count     403132
# unique         2
# top            M
# freq      313715
# Name: sex, dtype: object

# %%
df.sex.value_counts()
# Out:
# M    313715
# W     89417
# Name: sex, dtype: int64

# %%
no_sex = df[df.sex.isnull()]
len(no_sex)
# Out:
# 2

# %%
no_sex
# Out:
#            place    bib    surname  forename team nationality   yob  sex  \
# id
# 201677124  27472   6956     Barris   Wolfram  NaN         NaN  1951  NaN
# 201678774  26936  40651  Schnetzer  Wolfgang  NaN         NaN  1961  NaN
#
#           age_class  age_class_place net_time clock_time  year
# id
# 201677124       NaN              191 04:43:58   05:00:42  2016
# 201678774       NaN             1509 04:41:32   05:15:56  2016

# %%
df.sex = df.sex.fillna('M').astype('category')
df.sex.isnull().max()
# Out:
# False

# %% [markdown]
# ## Year of Birth (YOB)

# %%
df.yob.describe()
# Out:
# count    403134.000000
# mean       1967.243013
# std          47.518969
# min           0.000000
# 25%        1962.000000
# 50%        1968.000000
# 75%        1976.000000
# max        1998.000000
# Name: yob, dtype: float64

# %%
len(df[df.yob.isnull()])
# Out:
# 0

# %%
no_yob = df[df.yob == 0]
no_yob.head()
# Out:
#           place    bib       surname   forename   team nationality  yob sex  \
# id
# 2005717   22020   2119        Romero    Michael    NaN         GER    0   M
# 2005946    7679   2681         Tofte  Poul Erik  TRI 4         DEN    0   M
# 20051058  12767   3574    Lauterbach      Klaus    NaN         GER    0   M
# 20051546  30256  F1495         Ewald     Gisela    NaN         GER    0   W
# 20051853  11550   3249  Breidenstein     Volker    NaN         GER    0   M
#
#          age_class  age_class_place net_time clock_time  year
# id
# 2005717         MH             1964 04:34:08   04:38:11  2005
# 2005946         MH              746 03:42:02   03:45:02  2005
# 20051058        MH             1170 03:58:59   04:01:17  2005
# 20051546        WH              874 06:09:28   06:11:03  2005
# 20051853        MH             1068 03:55:56   03:58:50  2005

# %%
df.yob = df.yob.replace(0, np.nan)
df.yob.describe()
# Out:
# count    402910.000000
# mean       1968.336713
# std          10.321517
# min        1901.000000
# 25%        1962.000000
# 50%        1968.000000
# 75%        1976.000000
# max        1998.000000
# Name: yob, dtype: float64

# %% [markdown]
# It is unlikely to have a YOB of 1901.

# %%
df.yob.value_counts().sort_index().head(10)
# Out:
# 1901.0    22
# 1902.0     3
# 1923.0     2
# 1925.0     2
# 1926.0     5
# 1927.0    12
# 1928.0    12
# 1929.0     8
# 1930.0    11
# 1931.0    22
# Name: yob, dtype: int64

# %%
df['age'] = df.year - df.yob
df[df.yob <= 1925].sort_values(['yob', 'age'], ascending=[True, False])[['year', 'yob', 'age', 'age_class', 'net_time', 'place', 'age_class_place']]
# Out:
#            year     yob    age age_class net_time  place  age_class_place
# id
# 201681102  2016  1901.0  115.0       NaN 03:05:59   2126                0
# 20105394   2010  1901.0  109.0         W 04:00:01  16646                0
# 20108584   2010  1901.0  109.0         M 04:09:04  19394                0
# 20109381   2010  1901.0  109.0         M 03:54:42  14287                0
# 201015909  2010  1901.0  109.0         M 04:50:29  29460                0
# 201016059  2010  1901.0  109.0         W 05:02:11  31018                0
# 201017069  2010  1901.0  109.0         M 04:09:35  19565                0
# 201020199  2010  1901.0  109.0         M 03:08:16   2071                0
# 201026575  2010  1901.0  109.0         M 03:40:54   9474                0
# 201027772  2010  1901.0  109.0         M 03:41:56   9751                0
# 201028158  2010  1901.0  109.0         W 05:01:29  30959                0
# 201029504  2010  1901.0  109.0         M 02:49:48    460                0
# 201030469  2010  1901.0  109.0         M 03:37:32   8467                0
# 201032578  2010  1901.0  109.0         W 04:47:52  29034                0
# 20092358   2009  1901.0  108.0        MH 04:33:53  24617             2274
# 200910996  2009  1901.0  108.0        MH 04:40:52  26378             2405
# 200927829  2009  1901.0  108.0        MH 03:57:45  13536             1340
# 200928509  2009  1901.0  108.0        WH 04:43:34  27056              652
# 200929774  2009  1901.0  108.0        MH 04:06:50  16460             1599
# 200930133  2009  1901.0  108.0        MH 03:51:03  11064             1111
# 200936049  2009  1901.0  108.0        MH 04:24:10  21907             2071
# 200936051  2009  1901.0  108.0        MH 03:27:01   4755              557
# 201010895  2010  1902.0  108.0         M 03:52:07  13285                0
# 201016758  2010  1902.0  108.0         W 05:05:23  31290                0
# 200932419  2009  1902.0  107.0        MH 03:13:28   2460              309
# 200917972  2009  1923.0   86.0       M80 06:42:35  35006                5
# 2005113    2005  1923.0   82.0       M80 06:55:52  30381                2
# 20074024   2007  1925.0   82.0       W80 06:01:59  32286                1
# 20056807   2005  1925.0   80.0       M80 04:31:53  21492                1

# %%
df.yob = df.yob.replace(1901, np.nan).replace(1902, np.nan)

# %% [markdown]
# Once we have cleaned up the age class, we can use this information to guess the YOB.

# %% [markdown]
# Are some listed as too young to participate?

# %%
df['age'] = df.year - df.yob
df[df.age < 18]
# Out:
#            place    bib    surname       forename            team nationality  \
# id
# 20052685    7246   5257     Koepke        Mathias     Mahlower SV         GER
# 20055704   26060   5466   Jacobsen  Eystein André             NaN         NOR
# 200531437   4107  29736  Petrausch          Janek   Schenker-TEAM         GER
# 2007915    20059   2446   Musielak         Norman             NaN         DEU
# 20071154   30028  F1332    Scharpf          Maria  Scharpf-Family         DEU
# 200717477  32343  F6340      Garbe        Tabitha             NaN         DEU
# 200910843  24928  22567  Oppermann        Patrick             NaN         DEU
# 20104134   20039  F8916   Forsberg          Sofie             MTC         DNK
#
#               yob sex age_class  age_class_place net_time clock_time  year  \
# id
# 20052685   1988.0   M       MJA               18 03:40:18   03:40:58  2005
# 20055704   1988.0   M       MJA               97 04:55:34   04:59:23  2005
# 200531437  1988.0   M       MJA                9 03:26:21   03:28:55  2005
# 2007915    1990.0   M       MJA               84 04:15:32   04:15:52  2007
# 20071154   1990.0   W       WJA               23 05:09:06   05:15:09  2007
# 200717477  1990.0   W       WJA               29 06:07:53   06:10:04  2007
# 200910843  1995.0   M       MJA               79 04:35:04   04:42:02  2009
# 20104134   1993.0   W       WJA                7 04:11:04   04:33:41  2010
#
#             age
# id
# 20052685   17.0
# 20055704   17.0
# 200531437  17.0
# 2007915    17.0
# 20071154   17.0
# 200717477  17.0
# 200910843  14.0
# 20104134   17.0

# %% [markdown]
# ## Age Class

# %%
df.age_class.describe()
# Out:
# count     403105
# unique        42
# top           45
# freq       38433
# Name: age_class, dtype: object

# %%
no_age_class = df[df.age_class.isnull()]
len(no_age_class)
# Out:
# 29

# %%
no_age_class.head()
# Out:
#            place    bib     surname   forename        team nationality  \
# id
# 201220259  12554   3612  Adriaansen       Dave         NaN         NLD
# 201228086  22822  33294       Hocke    Michael          DB         DEU
# 201228871  32527  27010  Steffensen     Bjarne         NaN         DNK
# 201232991    585  15426  van Keulen     Louran  AP-running         NLD
# 201233353  18654  F7913  Szpakowska  Agnieszka         NaN         DEU
#
#               yob sex age_class  age_class_place net_time clock_time  year  \
# id
# 201220259  1977.0   M       NaN                0 03:49:46   04:00:05  2012
# 201228086     NaN   M       NaN                0 04:21:03   04:43:22  2012
# 201228871     NaN   M       NaN                0 05:22:28   05:45:36  2012
# 201232991     NaN   M       NaN                0 02:52:23   02:52:31  2012
# 201233353     NaN   W       NaN                0 04:06:25   04:23:04  2012
#
#             age
# id
# 201220259  35.0
# 201228086   NaN
# 201228871   NaN
# 201232991   NaN
# 201233353   NaN

# %%
df.age_class.value_counts().sort_index()
# Out:
# 30     25394
# 35     30177
# 40     38211
# 45     38433
# 50     28243
# 55     13845
# 60      6461
# 65      2477
# 70       971
# 75       255
# 80        37
# H      20298
# JA       420
# M         25
# M30    18301
# M35    26373
# M40    33912
# M45    27643
# M50    17945
# M55     9114
# M60     4376
# M65     2058
# M70      597
# M75       82
# M80       15
# MH     16315
# MJA      724
# U20       95
# W          8
# W30     5474
# W35     6598
# W40     8675
# W45     7093
# W50     4033
# W55     1618
# W60      584
# W65      251
# W70       50
# W75        3
# W80        5
# WH      5742
# WJA      174
# Name: age_class, dtype: int64

# %%
len(df[df.age_class.str.contains(r'[MW]', na=False)])
# Out:
# 197788

# %%
age_class_sex = df[df.age_class.str.contains(r'[MW]', na=False)].age_class.str.get(0)
len(age_class_sex)
# Out:
# 197788

# %%
inconsistent_sex0 = df.loc[age_class_sex.index, 'sex'] != age_class_sex
inconsistent_sex = df.loc[inconsistent_sex0[inconsistent_sex0 == True].index, :]
len(inconsistent_sex)
# Out:
# 34

# %%
inconsistent_sex
# Out:
#            place    bib      surname           forename  \
# id
# 200510341   1532  F3923      Lohmann             Henrik
# 200511280  14344  F5717      Sanchez               Raul
# 200523704  10930  F4420      Kachlik            Stephan
# 200523897   7434  F5646    Kirchhoff             Jochen
# 200528829   9129  F6506         Pape             Gerald
# 200533336  21772  F8928     Tricoche          Elisabeth
# 200537786   6827  32681      Filippo           Proietti
# 200537789  20204  32699     Demetrio            Alberto
# 20064614    2110  F3676         Aeby     Pascal Laurent
# 200616028    106  F7055    Nordgaard            Haavard
# 200641938  19813  32282        Filho           Lourival
# 200643722   1571  F7523     Basdekis             Pavlos
# 2007306    19484  F9642        Liden             Mikael
# 20072922   25182  F9645       Knaack             Oliver
# 20075922   12248  F2071  Himmelstein                Ari
# 20076571    3335  F9637       Holmes                Ben
# 20079038   32171  F9640     Wrzesien             Szymon
# 20079330   29549  F9643    Bergström            Fredrik
# 20079396    4775  33909  Ángel Ávila        Juan Manuel
# 20079497   24573  34121         Hyde               Kyle
# 200720252  15106  F9646      Eastman             Oliver
# 200721219   1270  F8957     Sørensen  Jytte Vestergaard
# 200729757   8923  34146        Frank         Vandenhole
# 200729964  26057  F9638      Richter              Frank
# 200733174  28164  F9639       Welber               Adam
# 200737911  20212    NaN      Middeke             Jasmin
# 20083667    4703  F1025       Maison             Sylvie
# 20087472   15536  37917       Macedo          Guilherme
# 20089951   23810  12454     Hautamaa               Anne
# 200820854  15085  37913      Michele              Tolin
# 200831461  22967  F5968      Morlang               René
# 200836818   4724  F7099        Rogoz           Grzegorz
# 200838362  16994  24442      Neuhaus             Svenja
# 200842364  33949  F9289      de Pape               Aldo
#
#                              team nationality     yob sex age_class  \
# id
# 200510341                  Sparta         DEN  1964.0   W       M40
# 200511280                     NaN         SUI  1962.0   W       M40
# 200523704                     NaN         GER  1963.0   W       M40
# 200523897           TSV Bollensen         GER  1957.0   W       M45
# 200528829      TriFrogs Gellersen         GER  1965.0   W       M40
# 200533336            Defi Horizon         FRA  1949.0   W       M55
# 200537786                     NaN         ITA  1967.0   M       W35
# 200537789                     NaN         BRA  1965.0   M       W40
# 20064614                      NaN         DEU  1966.0   W       M40
# 200616028                    Nike         NOR  1961.0   W       M45
# 200641938                  Brazil         BRA  1957.0   M       W45
# 200643722                     NaN         GRC  1946.0   W       M60
# 2007306                       NaN         SWE  1970.0   W       M35
# 20072922     Berlin Sluggers e.V.         DEU  1969.0   W       M35
# 20075922             The Team R&F         BRA  1961.0   W       M45
# 20076571                      NaN         GBR  1980.0   W        MH
# 20079038              Auto Buniks         POL  1988.0   W       MJA
# 20079330                      NaN         SWE     NaN   W        MH
# 20079396              Nacho Sport         ESP  1963.0   M       W40
# 20079497                      NaN         GBR  1982.0   M        WH
# 200720252                     NaN         GBR  1975.0   W       M30
# 200721219                     NaN         DNK  1960.0   W       M45
# 200729757                     NaN         FRA  1968.0   M       W35
# 200729964  Wilde Wölfe Holzweißig         DEU  1956.0   W       M50
# 200733174                     NaN         DEU  1970.0   W       M35
# 200737911                     NaN         DEU  1988.0   M       WJA
# 20083667                      NaN         FRA  1964.0   W       M40
# 20087472                      NaN         BRA  1980.0   M        WH
# 20089951                  Himanka         FIN  1959.0   M       W45
# 200820854                     NaN         ITA  1969.0   M       W35
# 200831461      BSG Deutscher Ring         DEU  1969.0   W       M35
# 200836818                     NaN         DEU  1969.0   W       M35
# 200838362                     NaN         DEU  1976.0   M       W35
# 200842364                     NaN         NLD  1979.0   W        MH
#
#            age_class_place net_time clock_time  year   age
# id
# 200510341              353 03:06:49   03:07:37  2005  41.0
# 200511280             3067 04:04:49   04:08:49  2005  43.0
# 200523704             2410 03:54:04   03:56:47  2005  42.0
# 200523897             1085 03:41:07   03:44:33  2005  48.0
# 200528829             2017 03:47:41   03:49:22  2005  40.0
# 200533336              840 04:33:09   04:37:12  2005  56.0
# 200537786              102 03:38:31   03:40:10  2005  38.0
# 200537789              677 04:26:27   04:30:40  2005  40.0
# 20064614               495 03:16:09   03:16:17  2006  40.0
# 200616028                3 02:38:57   02:39:04  2006  45.0
# 200641938              460 04:31:24   04:33:18  2006  49.0
# 200643722                5 03:11:03   03:11:27  2006  60.0
# 2007306               3192 04:13:29   04:14:52  2007  37.0
# 20072922              3830 04:35:38   04:36:56  2007  38.0
# 20075922              1914 03:52:12   03:55:13  2007  46.0
# 20076571               357 03:18:26   03:19:08  2007  27.0
# 20079038               119 05:54:43   05:56:55  2007  19.0
# 20079330              2558 05:03:28   05:04:51  2007   NaN
# 20079396                58 03:26:09   03:28:44  2007  44.0
# 20079497               549 04:32:42   04:33:03  2007  25.0
# 200720252             1733 03:58:57   04:02:33  2007  32.0
# 200721219              159 03:01:18   03:02:26  2007  47.0
# 200729757              129 03:41:50   03:42:01  2007  39.0
# 200729964             2290 04:40:06   04:42:31  2007  51.0
# 200733174             4116 04:52:41   04:54:15  2007  37.0
# 200737911               10 04:15:58   04:17:41  2007  19.0
# 20083667              1082 03:22:29   03:22:55  2008  44.0
# 20087472               258 03:56:58   04:01:31  2008  28.0
# 20089951               589 04:22:10   04:24:49  2008  49.0
# 200820854              283 03:55:55   03:58:28  2008  39.0
# 200831461             3402 04:19:17   04:21:33  2008  39.0
# 200836818              981 03:22:37   03:24:11  2008  39.0
# 200838362             2725 03:59:50   04:14:42  2008  32.0
# 200842364             2859 05:20:02   05:24:52  2008  29.0

# %%
inconsistent_sex.sex = inconsistent_sex.age_class.str.get(0)
inconsistent_sex
# Out:
#            place    bib      surname           forename  \
# id
# 200510341   1532  F3923      Lohmann             Henrik
# 200511280  14344  F5717      Sanchez               Raul
# 200523704  10930  F4420      Kachlik            Stephan
# 200523897   7434  F5646    Kirchhoff             Jochen
# 200528829   9129  F6506         Pape             Gerald
# 200533336  21772  F8928     Tricoche          Elisabeth
# 200537786   6827  32681      Filippo           Proietti
# 200537789  20204  32699     Demetrio            Alberto
# 20064614    2110  F3676         Aeby     Pascal Laurent
# 200616028    106  F7055    Nordgaard            Haavard
# 200641938  19813  32282        Filho           Lourival
# 200643722   1571  F7523     Basdekis             Pavlos
# 2007306    19484  F9642        Liden             Mikael
# 20072922   25182  F9645       Knaack             Oliver
# 20075922   12248  F2071  Himmelstein                Ari
# 20076571    3335  F9637       Holmes                Ben
# 20079038   32171  F9640     Wrzesien             Szymon
# 20079330   29549  F9643    Bergström            Fredrik
# 20079396    4775  33909  Ángel Ávila        Juan Manuel
# 20079497   24573  34121         Hyde               Kyle
# 200720252  15106  F9646      Eastman             Oliver
# 200721219   1270  F8957     Sørensen  Jytte Vestergaard
# 200729757   8923  34146        Frank         Vandenhole
# 200729964  26057  F9638      Richter              Frank
# 200733174  28164  F9639       Welber               Adam
# 200737911  20212    NaN      Middeke             Jasmin
# 20083667    4703  F1025       Maison             Sylvie
# 20087472   15536  37917       Macedo          Guilherme
# 20089951   23810  12454     Hautamaa               Anne
# 200820854  15085  37913      Michele              Tolin
# 200831461  22967  F5968      Morlang               René
# 200836818   4724  F7099        Rogoz           Grzegorz
# 200838362  16994  24442      Neuhaus             Svenja
# 200842364  33949  F9289      de Pape               Aldo
#
#                              team nationality     yob sex age_class  \
# id
# 200510341                  Sparta         DEN  1964.0   M       M40
# 200511280                     NaN         SUI  1962.0   M       M40
# 200523704                     NaN         GER  1963.0   M       M40
# 200523897           TSV Bollensen         GER  1957.0   M       M45
# 200528829      TriFrogs Gellersen         GER  1965.0   M       M40
# 200533336            Defi Horizon         FRA  1949.0   M       M55
# 200537786                     NaN         ITA  1967.0   W       W35
# 200537789                     NaN         BRA  1965.0   W       W40
# 20064614                      NaN         DEU  1966.0   M       M40
# 200616028                    Nike         NOR  1961.0   M       M45
# 200641938                  Brazil         BRA  1957.0   W       W45
# 200643722                     NaN         GRC  1946.0   M       M60
# 2007306                       NaN         SWE  1970.0   M       M35
# 20072922     Berlin Sluggers e.V.         DEU  1969.0   M       M35
# 20075922             The Team R&F         BRA  1961.0   M       M45
# 20076571                      NaN         GBR  1980.0   M        MH
# 20079038              Auto Buniks         POL  1988.0   M       MJA
# 20079330                      NaN         SWE     NaN   M        MH
# 20079396              Nacho Sport         ESP  1963.0   W       W40
# 20079497                      NaN         GBR  1982.0   W        WH
# 200720252                     NaN         GBR  1975.0   M       M30
# 200721219                     NaN         DNK  1960.0   M       M45
# 200729757                     NaN         FRA  1968.0   W       W35
# 200729964  Wilde Wölfe Holzweißig         DEU  1956.0   M       M50
# 200733174                     NaN         DEU  1970.0   M       M35
# 200737911                     NaN         DEU  1988.0   W       WJA
# 20083667                      NaN         FRA  1964.0   M       M40
# 20087472                      NaN         BRA  1980.0   W        WH
# 20089951                  Himanka         FIN  1959.0   W       W45
# 200820854                     NaN         ITA  1969.0   W       W35
# 200831461      BSG Deutscher Ring         DEU  1969.0   M       M35
# 200836818                     NaN         DEU  1969.0   M       M35
# 200838362                     NaN         DEU  1976.0   W       W35
# 200842364                     NaN         NLD  1979.0   M        MH
#
#            age_class_place net_time clock_time  year   age
# id
# 200510341              353 03:06:49   03:07:37  2005  41.0
# 200511280             3067 04:04:49   04:08:49  2005  43.0
# 200523704             2410 03:54:04   03:56:47  2005  42.0
# 200523897             1085 03:41:07   03:44:33  2005  48.0
# 200528829             2017 03:47:41   03:49:22  2005  40.0
# 200533336              840 04:33:09   04:37:12  2005  56.0
# 200537786              102 03:38:31   03:40:10  2005  38.0
# 200537789              677 04:26:27   04:30:40  2005  40.0
# 20064614               495 03:16:09   03:16:17  2006  40.0
# 200616028                3 02:38:57   02:39:04  2006  45.0
# 200641938              460 04:31:24   04:33:18  2006  49.0
# 200643722                5 03:11:03   03:11:27  2006  60.0
# 2007306               3192 04:13:29   04:14:52  2007  37.0
# 20072922              3830 04:35:38   04:36:56  2007  38.0
# 20075922              1914 03:52:12   03:55:13  2007  46.0
# 20076571               357 03:18:26   03:19:08  2007  27.0
# 20079038               119 05:54:43   05:56:55  2007  19.0
# 20079330              2558 05:03:28   05:04:51  2007   NaN
# 20079396                58 03:26:09   03:28:44  2007  44.0
# 20079497               549 04:32:42   04:33:03  2007  25.0
# 200720252             1733 03:58:57   04:02:33  2007  32.0
# 200721219              159 03:01:18   03:02:26  2007  47.0
# 200729757              129 03:41:50   03:42:01  2007  39.0
# 200729964             2290 04:40:06   04:42:31  2007  51.0
# 200733174             4116 04:52:41   04:54:15  2007  37.0
# 200737911               10 04:15:58   04:17:41  2007  19.0
# 20083667              1082 03:22:29   03:22:55  2008  44.0
# 20087472               258 03:56:58   04:01:31  2008  28.0
# 20089951               589 04:22:10   04:24:49  2008  49.0
# 200820854              283 03:55:55   03:58:28  2008  39.0
# 200831461             3402 04:19:17   04:21:33  2008  39.0
# 200836818              981 03:22:37   03:24:11  2008  39.0
# 200838362             2725 03:59:50   04:14:42  2008  32.0
# 200842364             2859 05:20:02   05:24:52  2008  29.0

# %%
wrong = {20087472, 200729757, 20079396, 200641938, 200537789, 200537786, 200533336}
fix_my_sex = inconsistent_sex[inconsistent_sex.index.isin(wrong)]
fix_my_sex
# Out:
#            place    bib      surname     forename          team nationality  \
# id
# 200533336  21772  F8928     Tricoche    Elisabeth  Defi Horizon         FRA
# 200537786   6827  32681      Filippo     Proietti           NaN         ITA
# 200537789  20204  32699     Demetrio      Alberto           NaN         BRA
# 200641938  19813  32282        Filho     Lourival        Brazil         BRA
# 20079396    4775  33909  Ángel Ávila  Juan Manuel   Nacho Sport         ESP
# 200729757   8923  34146        Frank   Vandenhole           NaN         FRA
# 20087472   15536  37917       Macedo    Guilherme           NaN         BRA
#
#               yob sex age_class  age_class_place net_time clock_time  year  \
# id
# 200533336  1949.0   M       M55              840 04:33:09   04:37:12  2005
# 200537786  1967.0   W       W35              102 03:38:31   03:40:10  2005
# 200537789  1965.0   W       W40              677 04:26:27   04:30:40  2005
# 200641938  1957.0   W       W45              460 04:31:24   04:33:18  2006
# 20079396   1963.0   W       W40               58 03:26:09   03:28:44  2007
# 200729757  1968.0   W       W35              129 03:41:50   03:42:01  2007
# 20087472   1980.0   W        WH              258 03:56:58   04:01:31  2008
#
#             age
# id
# 200533336  56.0
# 200537786  38.0
# 200537789  40.0
# 200641938  49.0
# 20079396   44.0
# 200729757  39.0
# 20087472   28.0

# %%
fix_my_sex.sex = fix_my_sex.sex.apply(lambda s: 'W' if s == 'M' else 'M')
df.loc[fix_my_sex.index, 'sex'] = fix_my_sex.sex
df.loc[fix_my_sex.index, :]
# Out:
# /home/brian/.virtualenvs/generic/lib/python3.5/site-packages/pandas/core/generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
#            place    bib      surname     forename          team nationality  \
# id
# 200533336  21772  F8928     Tricoche    Elisabeth  Defi Horizon         FRA
# 200537786   6827  32681      Filippo     Proietti           NaN         ITA
# 200537789  20204  32699     Demetrio      Alberto           NaN         BRA
# 200641938  19813  32282        Filho     Lourival        Brazil         BRA
# 20079396    4775  33909  Ángel Ávila  Juan Manuel   Nacho Sport         ESP
# 200729757   8923  34146        Frank   Vandenhole           NaN         FRA
# 20087472   15536  37917       Macedo    Guilherme           NaN         BRA
#
#               yob sex age_class  age_class_place net_time clock_time  year  \
# id
# 200533336  1949.0   W       M55              840 04:33:09   04:37:12  2005
# 200537786  1967.0   M       W35              102 03:38:31   03:40:10  2005
# 200537789  1965.0   M       W40              677 04:26:27   04:30:40  2005
# 200641938  1957.0   M       W45              460 04:31:24   04:33:18  2006
# 20079396   1963.0   M       W40               58 03:26:09   03:28:44  2007
# 200729757  1968.0   M       W35              129 03:41:50   03:42:01  2007
# 20087472   1980.0   M        WH              258 03:56:58   04:01:31  2008
#
#             age
# id
# 200533336  56.0
# 200537786  38.0
# 200537789  40.0
# 200641938  49.0
# 20079396   44.0
# 200729757  39.0
# 20087472   28.0

# %%
df.age_class = df.age_class.str.replace(r'[MW]?(.*)', r'\1')
df.age_class.value_counts().sort_index()
# Out:
#           33
# 30     49169
# 35     63148
# 40     80798
# 45     73169
# 50     50221
# 55     24577
# 60     11421
# 65      4786
# 70      1618
# 75       340
# 80        57
# H      42355
# JA      1318
# U20       95
# Name: age_class, dtype: int64

# %%
no_ac = df[(df.age_class == "")]
no_ac
# Out:
#            place    bib         surname        forename  \
# id
# 20101501   27915  27762           Thiel         Stephan
# 20102084    1254  36577         Naumann          Daniel
# 20102087    3050  36580       Mindaugas          Garmus
# 20102093   10741  36590    Da Conceicao            Toni
# 20102443   27165  F8708      Castellari        Loredana
# 20102822   31303  31359          Bitzer       Christian
# 20103418    3218  31316         Besnard         Nicolas
# 20103419   14441  31792         Charles          Romain
# 20105394   16646  F5795         Padberg         Barbara
# 20108584   19394  27493          Talmas         Olivier
# 20109381   14287   1024          Bossig       Christian
# 201010895  13285  24912        Schlicht         Gunther
# 201011182  14715  26649     Spiekermann           Georg
# 201013887   9534    NaN            Coll         Florian
# 201015909  29460  25641      Schumacher         Amadeus
# 201016059  31018  F2960       Hahnemann           Maria
# 201016758  31290  F2826         Greiner             Eva
# 201017069  19565   5817         Brauner             Kai
# 201017432     27     36    Neuschwander         Florian
# 201017460    189    F20        Schnabel            Anja
# 201017529   2057     54        Pedrolli        Fabricio
# 201017561  20832  36638  Tolosa Jimenez           Pedro
# 201020199   2071  18175       Macarthur        Alistair
# 201026575   9474  10104        Frömberg         Torsten
# 201027772   9751  30441          Wowros  Michael-Thomas
# 201028158  30959  F7240     Speri-praus        Adelheid
# 201029504    460  21900           Peraz          Marino
# 201030469   8467  34864        Pedersen       Ole Bülow
# 201032578  29034  F8030          Walker        Michelle
# 201033512  22120  31910      Conscience           Alain
# 201033740   7611   6446         Cameron           Gavin
# 201033776  16414  F3310    Higginbottom           Clare
# 201033777   6995  21219        O´Mahony            John
#
#                             team nationality     yob sex age_class  \
# id
# 20101501                     NaN         DEU     NaN   M
# 20102084                     NaN         DEU     NaN   M
# 20102087                     NaN         DEU     NaN   M
# 20102093                     NaN         DEU     NaN   M
# 20102443                     NaN         ITA     NaN   W
# 20102822                  adidas         DEU     NaN   M
# 20103418      real,- Gewinnspiel         FRA     NaN   M
# 20103419      real,- Gewinnspiel         FRA     NaN   M
# 20105394                     NaN         DEU     NaN   W
# 20108584                Next One         BEL     NaN   M
# 20109381                     NaN         DEU     NaN   M
# 201010895        Helios Kliniken         DEU     NaN   M
# 201011182                    NaN         DEU     NaN   M
# 201013887           Cours Forest         FRA  1983.0   M
# 201015909                    NaN         DEU     NaN   M
# 201016059                    NaN         DEU     NaN   W
# 201016758  Team Radsport Greiner         DEU     NaN   W
# 201017069                    NaN         DEU     NaN   M
# 201017432                    NaN         DEU     NaN   M
# 201017460                    NaN         DEU     NaN   W
# 201017529                    NaN         ITA     NaN   M
# 201017561  Club Atletismo Ibañes         ESP     NaN   M
# 201020199                    NaN         GBR     NaN   M
# 201026575                    NaN         DEU     NaN   M
# 201027772     1. Fc Union Berlin         DEU     NaN   M
# 201028158                    NaN         DEU     NaN   W
# 201029504                    NaN         ITA     NaN   M
# 201030469             Club Århus         DNK     NaN   M
# 201032578                    NaN         GBR     NaN   W
# 201033512          ASTB Besancon         FRA     NaN   M
# 201033740                    NaN         GBR     NaN   M
# 201033776                    NaN         GBR     NaN   W
# 201033777                    NaN         GBR     NaN   M
#
#            age_class_place net_time clock_time  year   age
# id
# 20101501                 0 04:41:51   05:06:28  2010   NaN
# 20102084                 0 02:59:23   02:59:52  2010   NaN
# 20102087                 0 03:14:59   03:14:59  2010   NaN
# 20102093                 0 03:45:01   03:54:56  2010   NaN
# 20102443                 0 04:38:07   04:58:51  2010   NaN
# 20102822                 0 05:05:31   05:28:21  2010   NaN
# 20103418                 0 03:16:04   03:18:35  2010   NaN
# 20103419                 0 03:55:05   04:10:37  2010   NaN
# 20105394                 0 04:00:01   04:03:32  2010   NaN
# 20108584                 0 04:09:04   04:20:52  2010   NaN
# 20109381                 0 03:54:42   03:57:56  2010   NaN
# 201010895                0 03:52:07   04:03:09  2010   NaN
# 201011182                0 03:55:47   04:18:35  2010   NaN
# 201013887                0 03:41:07   03:52:11  2010  27.0
# 201015909                0 04:50:29   05:07:19  2010   NaN
# 201016059                0 05:02:11   05:20:42  2010   NaN
# 201016758                0 05:05:23   05:26:10  2010   NaN
# 201017069                0 04:09:35   04:25:29  2010   NaN
# 201017432                0 02:23:58   02:23:58  2010   NaN
# 201017460                0 02:41:41   02:41:41  2010   NaN
# 201017529                0 03:08:06   03:08:08  2010   NaN
# 201017561                0 04:13:47   04:32:36  2010   NaN
# 201020199                0 03:08:16   03:11:40  2010   NaN
# 201026575                0 03:40:54   03:44:13  2010   NaN
# 201027772                0 03:41:56   03:42:31  2010   NaN
# 201028158                0 05:01:29   05:23:22  2010   NaN
# 201029504                0 02:49:48   02:49:54  2010   NaN
# 201030469                0 03:37:32   03:38:21  2010   NaN
# 201032578                0 04:47:52   05:06:37  2010   NaN
# 201033512                0 04:18:09   04:27:36  2010   NaN
# 201033740                0 03:34:26   03:39:15  2010   NaN
# 201033776                0 03:59:28   04:10:01  2010   NaN
# 201033777                0 03:32:15   03:45:27  2010   NaN

# %%
df.age_class = df.age_class.replace('', np.nan)
len(df[df.age_class == ""])
# Out:
# 0

# %%
df.groupby('age_class').age.aggregate([np.min, np.median, np.max])
# Out:
#            amin  median  amax
# age_class
# 30         30.0    32.0  54.0
# 35         32.0    37.0  40.0
# 40         39.0    42.0  44.0
# 45         45.0    47.0  49.0
# 50         47.0    52.0  54.0
# 55         55.0    56.0  59.0
# 60         60.0    61.0  64.0
# 65         65.0    66.0  69.0
# 70         60.0    71.0  74.0
# 75         75.0    76.0  79.0
# 80         80.0    81.0  86.0
# H          20.0    27.0  48.0
# JA         14.0    19.0  19.0
# U20        18.0    19.0  19.0

# %%
df[(df.age_class == '30') & (df.age >= 35)]
# Out:
#            place    bib surname forename             team nationality     yob  \
# id
# 200834733   4928  36826   Silva    Usiel  Rho Delta Trave         BRA  1954.0
#
#           sex age_class  age_class_place net_time clock_time  year   age
# id
# 200834733   M        30              677 03:23:32   03:23:38  2008  54.0

# %%
df.set_value(200834733, 'age_class', '50')

df[(df.age_class == '50') & (df.age < 50)]
# Out:
#            place    bib      surname   forename team nationality     yob sex  \
# id
# 20088907    2532  17349       Lameir  Christian  NaN         DEU  1959.0   M
# 201232192  20225  13846  Hundertmark      Peter  NaN         DEU  1965.0   M
#
#           age_class  age_class_place net_time clock_time  year   age
# id
# 20088907         50              155 03:10:18   03:10:26  2008  49.0
# 201232192        50             2125 04:12:00   04:22:19  2012  47.0

# %%
df.set_value(201232192, 'age_class', '45')

df[(df.age_class == '70') & (df.age < 70)]
# Out:
#            place    bib   surname forename      team nationality     yob sex  \
# id
# 200916097  28932   F174  Kiederle    Inger  Atletica         DNK  1942.0   W
# 200932876  20390  37361     Thiel    Peter       NaN         DEU  1949.0   M
#
#           age_class  age_class_place net_time clock_time  year   age
# id
# 200916097        70                3 04:52:07   05:07:35  2009  67.0
# 200932876        70               19 04:19:01   04:30:43  2009  60.0

# %%
df.set_value(200916097, 'age_class', '65')
df.set_value(200932876, 'age_class', '60')

df[(df.age_class == 'H') & (df.age >= 30)]
# Out:
#            place    bib   surname   forename                team nationality  \
# id
# 200722121     41     84    Güssow  Christian        Hamburger SV         DEU
# 200919946  14485  23852  Pranzner    Andreas  Berliner Feuerwehr         DEU
#
#               yob sex age_class  age_class_place net_time clock_time  year  \
# id
# 200722121  1976.0   M         H               17 02:27:05   02:27:08  2007
# 200919946  1961.0   M         H             1415 04:00:00   04:19:35  2009
#
#             age
# id
# 200722121  31.0
# 200919946  48.0

# %%
df.set_value(200722121, 'age_class', '30')
df.set_value(200919946, 'age_class', '45')
len(df)
# Out:
# 403134

# %%
def upper(match):
    if match.group(2) == '0':
        d = '4'
    else:
        d = '9'
    return '{0}-{1}{2}'.format(match.group(0), match.group(1), d)

df.age_class = df.age_class.str.replace(r'^(JA|U20)$', '0-19').str.replace('^H$', '20-29').str.replace(r'^8.*', '80+').str.replace(r'^(\d)(\d)$', upper)
df.groupby('age_class').age.aggregate([np.min, np.max])
# Out:
#            amin  amax
# age_class
# 0-19       14.0  19.0
# 20-29      20.0  29.0
# 30-34      30.0  34.0
# 35-39      32.0  40.0
# 40-44      39.0  44.0
# 45-49      45.0  49.0
# 50-54      49.0  54.0
# 55-59      55.0  59.0
# 60-64      60.0  64.0
# 65-69      65.0  69.0
# 70-74      70.0  74.0
# 75-79      75.0  79.0
# 80+        80.0  86.0

# %%
age_classes = pd.unique(df.age_class.dropna())
df.age_class = df.age_class.astype('category', categories=age_classes, ordered=True)

# %% [markdown]
# ## Age Class Place

# %%
df.age_class_place.describe()
# Out:
# count    403134.000000
# mean       1596.684058
# std        1321.932040
# min           0.000000
# 25%         517.000000
# 50%        1208.000000
# 75%        2456.000000
# max        6101.000000
# Name: age_class_place, dtype: float64

# %%
len(df[df.age_class_place.isnull()])
# Out:
# 0

# %%
df.age_class_place = df.age_class_place.replace(0, np.nan)
zero_acp = df[df.age_class_place.isnull()]
zero_acp[['age_class', 'place', 'net_time', 'clock_time', 'year', 'yob', 'age']]
# Out:
#            age_class  place net_time clock_time  year     yob   age
# id
# 20101501         NaN  27915 04:41:51   05:06:28  2010     NaN   NaN
# 20102084         NaN   1254 02:59:23   02:59:52  2010     NaN   NaN
# 20102087         NaN   3050 03:14:59   03:14:59  2010     NaN   NaN
# 20102093         NaN  10741 03:45:01   03:54:56  2010     NaN   NaN
# 20102443         NaN  27165 04:38:07   04:58:51  2010     NaN   NaN
# 20102822         NaN  31303 05:05:31   05:28:21  2010     NaN   NaN
# 20103418         NaN   3218 03:16:04   03:18:35  2010     NaN   NaN
# 20103419         NaN  14441 03:55:05   04:10:37  2010     NaN   NaN
# 20105394         NaN  16646 04:00:01   04:03:32  2010     NaN   NaN
# 20108584         NaN  19394 04:09:04   04:20:52  2010     NaN   NaN
# 20109381         NaN  14287 03:54:42   03:57:56  2010     NaN   NaN
# 201010895        NaN  13285 03:52:07   04:03:09  2010     NaN   NaN
# 201011182        NaN  14715 03:55:47   04:18:35  2010     NaN   NaN
# 201013887        NaN   9534 03:41:07   03:52:11  2010  1983.0  27.0
# 201015909        NaN  29460 04:50:29   05:07:19  2010     NaN   NaN
# 201016059        NaN  31018 05:02:11   05:20:42  2010     NaN   NaN
# 201016758        NaN  31290 05:05:23   05:26:10  2010     NaN   NaN
# 201017069        NaN  19565 04:09:35   04:25:29  2010     NaN   NaN
# 201017432        NaN     27 02:23:58   02:23:58  2010     NaN   NaN
# 201017460        NaN    189 02:41:41   02:41:41  2010     NaN   NaN
# 201017529        NaN   2057 03:08:06   03:08:08  2010     NaN   NaN
# 201017561        NaN  20832 04:13:47   04:32:36  2010     NaN   NaN
# 201020199        NaN   2071 03:08:16   03:11:40  2010     NaN   NaN
# 201026575        NaN   9474 03:40:54   03:44:13  2010     NaN   NaN
# 201027772        NaN   9751 03:41:56   03:42:31  2010     NaN   NaN
# 201028158        NaN  30959 05:01:29   05:23:22  2010     NaN   NaN
# 201029504        NaN    460 02:49:48   02:49:54  2010     NaN   NaN
# 201030469        NaN   8467 03:37:32   03:38:21  2010     NaN   NaN
# 201032578        NaN  29034 04:47:52   05:06:37  2010     NaN   NaN
# 201033512        NaN  22120 04:18:09   04:27:36  2010     NaN   NaN
# ...              ...    ...      ...        ...   ...     ...   ...
# 201220259        NaN  12554 03:49:46   04:00:05  2012  1977.0  35.0
# 201226984      40-44   6633 03:29:36   03:35:05  2012  1969.0  43.0
# 201228086        NaN  22822 04:21:03   04:43:22  2012     NaN   NaN
# 201228871        NaN  32527 05:22:28   05:45:36  2012     NaN   NaN
# 201232991        NaN    585 02:52:23   02:52:31  2012     NaN   NaN
# 201233353        NaN  18654 04:06:25   04:23:04  2012     NaN   NaN
# 201235116        NaN   6993 03:30:53   03:32:05  2012     NaN   NaN
# 201235190        NaN  10668 03:44:06   03:53:38  2012     NaN   NaN
# 201235191        NaN  10565 03:43:51   03:53:36  2012     NaN   NaN
# 201235198        NaN  15570 03:57:33   04:07:46  2012     NaN   NaN
# 201235200        NaN  25140 04:29:19   04:50:28  2012     NaN   NaN
# 2013166          NaN     36 02:21:48   02:21:48  2013     NaN   NaN
# 2013204          NaN   5889 03:25:54   03:25:54  2013     NaN   NaN
# 2013231          NaN  18962 04:01:38   04:01:38  2013     NaN   NaN
# 2013396          NaN     33 02:21:34   02:21:34  2013     NaN   NaN
# 2013681          NaN  15701 03:54:34   04:25:58  2013     NaN   NaN
# 2013757          NaN      6 02:09:24   02:09:24  2013     NaN   NaN
# 2013760          NaN      8 02:11:31   02:11:31  2013     NaN   NaN
# 20132164         NaN     30 02:21:11   02:21:11  2013     NaN   NaN
# 201313716        NaN  26230 04:26:24   04:58:54  2013     NaN   NaN
# 20141580         NaN   4472 03:24:59   03:25:11  2014     NaN   NaN
# 201427663        NaN    757 02:55:24   02:55:59  2014     NaN   NaN
# 201593204      35-39   3633 03:13:33   03:14:14  2015  1979.0  36.0
# 2015101622     35-39     20 02:14:51   02:14:51  2015  1976.0  39.0
# 2015141090       NaN  36483 06:10:32   06:46:46  2015  1956.0  59.0
# 2015141108       NaN  35431 05:36:47   06:16:10  2015  1976.0  39.0
# 2015141111       NaN   9428 03:36:51   03:56:07  2015  1980.0  35.0
# 2015141114       NaN  19328 04:04:35   04:24:01  2015  1975.0  40.0
# 2015141120       NaN  18143 04:00:32   04:23:56  2015  1975.0  40.0
# 201681102        NaN   2126 03:05:59   03:08:23  2016     NaN   NaN
#
# [63 rows x 7 columns]

# %%
missing_ac = df[(df.age_class_place.isnull()) & (df.age_class.isnull()) & (~df.yob.isnull())]
missing_ac.age_class = (5 * (missing_ac.age // 5)).astype('int').astype('str').str.replace(r'^(\d)(\d)$', upper)
missing_ac
# Out:
# /home/brian/.virtualenvs/generic/lib/python3.5/site-packages/pandas/core/generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
#             place     bib     surname   forename                   team  \
# id
# 201013887    9534     NaN        Coll    Florian           Cours Forest
# 201220259   12554    3612  Adriaansen       Dave                    NaN
# 2015141090  36483  F12454      Stasch    Christa                    NaN
# 2015141108  35431   38838        Wang  Hsi-Tsang                    NaN
# 2015141111   9428   38825   Heinrichs     Markus  SCW München Triathlon
# 2015141114  19328   38827        Huai  Qianjiang                    NaN
# 2015141120  18143   38828       Kraus     Martin                    NaN
#
#            nationality     yob sex age_class  age_class_place net_time  \
# id
# 201013887          FRA  1983.0   M     25-29              NaN 03:41:07
# 201220259          NLD  1977.0   M     35-39              NaN 03:49:46
# 2015141090         GER  1956.0   W     55-59              NaN 06:10:32
# 2015141108         TPE  1976.0   M     35-39              NaN 05:36:47
# 2015141111         GER  1980.0   M     35-39              NaN 03:36:51
# 2015141114         CHN  1975.0   M     40-44              NaN 04:04:35
# 2015141120         GER  1975.0   M     40-44              NaN 04:00:32
#
#            clock_time  year   age
# id
# 201013887    03:52:11  2010  27.0
# 201220259    04:00:05  2012  35.0
# 2015141090   06:46:46  2015  59.0
# 2015141108   06:16:10  2015  39.0
# 2015141111   03:56:07  2015  35.0
# 2015141114   04:24:01  2015  40.0
# 2015141120   04:23:56  2015  40.0

# %%
missing_ac.set_value(201013887, 'age_class', '20-29')
df.loc[missing_ac.index, 'age_class'] = missing_ac.age_class

# %% [markdown]
# ### Consistent Ordering

# %%
df['clean_place'] = df.groupby('year').net_time.rank(method='max', na_option='bottom')
df['clean_age_class_place'] = df.groupby(['year', 'age_class']).net_time.rank(method='max', na_option='bottom')
df['super_place'] = df.net_time.rank(method='max', na_option='bottom')
df['super_age_class_place'] = df.net_time.rank(method='max', na_option='bottom')
df.sample(10)
# Out:
#            place    bib                surname  forename            team  \
# id
# 20051937   19848   3302            Wonneberger    Martin             NaN
# 201120851  12677  F5163               Martinez    Sondra             NaN
# 201318649  33082   F510              Abruzzini      Vera  PN TREINAMENTO
# 201133672  15992  34695                 Timmer    Martin             NaN
# 200933231  30232   6689                Bucksch     Klaus             NaN
# 200626597  25881  32118              Neidhardt   Michael             NaN
# 2013424     4400  19107              Mühleisen    Stefan      Teamadidas
# 200816510  10508  23850  Ravnholdt Frederiksen      Lars         KTT2000
# 200825650   9360  27731              Soy Fusté      Joan             NaN
# 201319488   1714  24876                 SIKORA  GRZEGORZ             NaN
#
#           nationality     yob sex age_class  age_class_place net_time  \
# id
# 20051937          GER  1984.0   M     20-29           1784.0 04:25:03
# 201120851         USA  1976.0   W     35-39            265.0 03:54:44
# 201318649         BRA  1963.0   W     50-54            994.0 05:00:46
# 201133672         NLD  1953.0   M     55-59            625.0 04:03:41
# 200933231         DEU  1956.0   M     50-54           2845.0 04:59:15
# 200626597         DEU  1963.0   M     40-44           4869.0 05:02:06
# 2013424           DEU  1979.0   M     30-34            676.0 03:19:25
# 200816510         DNK  1974.0   M     30-34           1278.0 03:43:29
# 200825650         ESP  1965.0   M     40-44           2070.0 03:39:46
# 201319488         POL  1983.0   M     30-34            342.0 03:02:43
#
#           clock_time  year   age  clean_place  clean_age_class_place  \
# id
# 20051937    04:28:35  2005  21.0      19846.0                 2185.0
# 201120851   04:03:06  2011  35.0      12682.0                 2135.0
# 201318649   05:25:22  2013  50.0      33003.0                 4510.0
# 201133672   04:11:54  2011  58.0      15991.0                  668.0
# 200933231   05:13:28  2009  53.0      30231.0                 3391.0
# 200626597   05:04:14  2006  43.0      25873.0                 5945.0
# 2013424     03:22:55  2013  34.0       4395.0                  712.0
# 200816510   03:45:30  2008  34.0      10503.0                 1413.0
# 200825650   03:41:51  2008  43.0       9357.0                 2222.0
# 201319488   03:09:20  2013  30.0       1711.0                  351.0
#
#            super_place  super_age_class_place
# id
# 20051937      271103.0               271103.0
# 201120851     159368.0               159368.0
# 201318649     356405.0               356405.0
# 201133672     199271.0               199271.0
# 200933231     354079.0               354079.0
# 200626597     358207.0               358207.0
# 2013424        44480.0                44480.0
# 200816510     115259.0               115259.0
# 200825650     102801.0               102801.0
# 201319488      18256.0                18256.0

# %% [markdown]
# ## Teams

# %%
df.team.describe()
# Out:
# count       181573
# unique       68777
# top       Terramia
# freq          1908
# Name: team, dtype: object

# %% [markdown]
# ## Nationality

# %%
df.nationality.describe()
# Out:
# count     403120
# unique       250
# top          DEU
# freq      155501
# Name: nationality, dtype: object

# %%
len(df[df.nationality.isnull()])
# Out:
# 14

# %% [markdown]
# [ISO](https://en.wikipedia.org/wiki/ISO_3166-1)
# [FIFA](https://en.wikipedia.org/wiki/List_of_FIFA_country_codes)
# [IOC](https://en.wikipedia.org/wiki/List_of_IOC_country_codes)

# %%
nat = pd.read_csv('../data/countries.csv')
nat.head()
# Out:
#   abbreviation iso3166_1alpha_3               country
# 0          ABW              ABW                 Aruba
# 1          AFG              AFG           Afghanistan
# 2          AGO              AGO                Angola
# 3          AHO              AHO  Netherlands Antilles
# 4          ALB              ALB               Albania

# %%
sorted(set(df.nationality.dropna()) - set(nat.abbreviation))
# Out:
# ['RKS']

# %%
df = pd.merge(df, nat, left_on='nationality', right_on='abbreviation', how='left').drop('nationality', axis=1)
df.iso3166_1alpha_3.describe()
# Out:
# count     403117
# unique       199
# top          DEU
# freq      192234
# Name: iso3166_1alpha_3, dtype: object

# %% [markdown]
# ## Names

# %%
df.forename.describe()
# Out:
# count     403089
# unique     37436
# top       Thomas
# freq        7865
# Name: forename, dtype: object

# %%
len(df[df.forename.isnull()])
# Out:
# 45

# %%
df[(df.forename.isnull()) & (~df.surname.isnull())]
# Out:
#         place    bib                             surname forename  \
# 60554   15749  29772  Chávez-Fernández Goyburu,Juan José      NaN
# 60901   31004  F1115                          Mackenzie,      NaN
# 94924   22570  F2721                   Elvers-Schreiber,      NaN
# 122234  17214  F2727            Emmanuelle Rochet-Blanc,      NaN
# 124378  34879  37896                           Williams,      NaN
# 124379  27883  37897                              Keith,      NaN
# 125273   4790  37898                           Witfield,      NaN
# 132211    836   6092                             Bosgoed      NaN
# 266361   6254  10087                              Gestin      NaN
#
#                           team     yob sex age_class  age_class_place  \
# 60554             Regatas Lima  1967.0   M     35-39           2771.0
# 60901                      NaN  1962.0   W     45-49           1028.0
# 94924               DAV Berlin  1951.0   W     55-59             86.0
# 122234  les chauffe la semelle  1968.0   W     40-44            433.0
# 124378                     NaN     NaN   M     20-29           2921.0
# 124379                     NaN     NaN   M     20-29           2452.0
# 125273                     NaN     NaN   M     20-29            503.0
# 132211                  ARO'88  1966.0   M     40-44            183.0
# 266361         CACL Courbevoie  1967.0   M     45-49           1086.0
#
#        net_time clock_time  year   age  clean_place  clean_age_class_place  \
# 60554  04:15:47   04:18:00  2006  39.0      15743.0                 3142.0
# 60901  05:21:45   05:29:38  2007  45.0      30993.0                 5337.0
# 94924  04:17:47   04:22:01  2008  57.0      22569.0                 1021.0
# 122234 04:00:22   04:06:18  2008  40.0      17210.0                 4043.0
# 124378 05:38:09   05:44:09  2008   NaN      34865.0                 3904.0
# 124379 04:37:34   04:41:15  2008   NaN      27869.0                 3097.0
# 125273 03:22:56   03:24:39  2008   NaN       4791.0                  560.0
# 132211 02:57:05   02:57:29  2009  43.0        837.0                  184.0
# 266361 03:27:16   03:30:36  2013  46.0       6249.0                 1145.0
#
#         super_place  super_age_class_place abbreviation iso3166_1alpha_3  \
# 60554      241063.0               241063.0          PER              PER
# 60901      379507.0               379507.0          NLD              NLD
# 94924      247750.0               247750.0          DEU              DEU
# 122234     187956.0               187956.0          FRA              FRA
# 124378     390558.0               390558.0          DEU              DEU
# 124379     307136.0               307136.0          GBR              GBR
# 125273      51816.0                51816.0          GBR              GBR
# 132211      11273.0                11273.0          NLD              NLD
# 266361      63193.0                63193.0          FRA              FRA
#
#                country
# 60554             Peru
# 60901      Netherlands
# 94924          Germany
# 122234          France
# 124378         Germany
# 124379  United Kingdom
# 125273  United Kingdom
# 132211     Netherlands
# 266361          France

# %%
df.surname.describe()
# Out:
# count      403096
# unique     127265
# top       Nielsen
# freq         1648
# Name: surname, dtype: object

# %%
len(df[df.surname.isnull()])
# Out:
# 38

# %%
df[(df.surname.isnull()) & (~df.forename.isnull())]
# Out:
#         place    bib surname   forename                team     yob sex  \
# 30385   12730  32232     NaN   Benjamin                 NaN  1982.0   M
# 148108    223  26347     NaN  Christoph  LAV Asics Tübingen  1984.0   M
#
#        age_class  age_class_place net_time clock_time  year   age  \
# 30385      20-29           1134.0 04:04:33   04:10:01  2006  24.0
# 148108     20-29             53.0 02:41:58   02:42:06  2009  25.0
#
#         clean_place  clean_age_class_place  super_place  \
# 30385       12726.0                 1342.0     202133.0
# 148108        223.0                   58.0       2791.0
#
#         super_age_class_place abbreviation iso3166_1alpha_3  country
# 30385                202133.0          DEU              DEU  Germany
# 148108                 2791.0          DEU              DEU  Germany

# %%
df.surname = df.surname.str.strip(string.punctuation)
df.forename = df.forename.str.strip(string.punctuation)

# %% [markdown]
# ## Bibs

# %%
df.bib.describe()
# Out:
# count     403127
# unique     59339
# top        F1007
# freq          37
# Name: bib, dtype: object

# %% [markdown]
# ## Save the Clean Data

# %%
df.dtypes
# Out:
# place                              int64
# bib                               object
# surname                           object
# forename                          object
# team                              object
# yob                              float64
# sex                             category
# age_class                       category
# age_class_place                  float64
# net_time                 timedelta64[ns]
# clock_time               timedelta64[ns]
# year                               int64
# age                              float64
# clean_place                      float64
# clean_age_class_place            float64
# super_place                      float64
# super_age_class_place            float64
# abbreviation                      object
# iso3166_1alpha_3                  object
# country                           object
# dtype: object

# %%
df.sort_values(['year', 'place', 'clock_time']).to_csv(clean_filename)
